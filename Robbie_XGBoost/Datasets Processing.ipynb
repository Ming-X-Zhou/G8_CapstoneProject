# %% [markdown]
# These codes originally created by Ming and I just remodified it to work on google colab version, in order for me to preprocess client datasets

# %%
# Mount Google Drive (run this code once to mount the drive)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_file_path = '/content/drive/MyDrive/ColabNotebooks/CH Counts Data.zip'

# %%
import pandas as pd
import zipfile
import os
import gc
import random

# Define constants
LABELS = [
    "Fe-Oxide", "Background", "Ilmenite", "Epidote", "Amphibole",
    "AlFe-Silicate", "Fe-Silicate", "Titanite", "AlMn-Silicate",
    "Rutile", "Zircon", "Monazite", "Quartz", "Cassiterite",
    "AlK-Silicate", "Barite", "Al-Silicate", "Chromite",
    "Leucoxene", "Fe-Sulphide", "AlCa-Silicate", "Apatite",
    "Xenotime", "Carbonate", "Thorite", "AlFe-Silicate_Zn",
    "Al-Oxide", "Fe-Sulphide_Cu", "W-Oxide", "Zn-Oxide",
    "Fe-sulphide_Pb", "Celestine", "Mn-Oxide", "Columbite_Mn",
    "Cu-Oxide", "Nb-bearing phase", "REE-Silicate", "Molybdenite"
]

TOTAL_SAMPLES = {
    "Fe-Oxide": 20883184,
    "Background": 11347230,
    "Ilmenite": 8400629,
    "Epidote": 5195663,
    "Amphibole": 4404669,
    "AlFe-Silicate": 4106622,
    "Fe-Silicate": 1784892,
    "Titanite": 1512827,
    "AlMn-Silicate": 1326232,
    "Rutile": 876502,
    "Zircon": 618053,
    "Monazite": 408111,
    "Quartz": 404580,
    "Cassiterite": 371466,
    "AlK-Silicate": 325675,
    "Barite": 281363,
    "Al-Silicate": 272677,
    "Chromite": 266954,
    "Leucoxene": 150346,
    "Fe-Sulphide": 146294,
    "AlCa-Silicate": 125414,
    "Apatite": 92279,
    "Xenotime": 66880,
    "Carbonate": 62444,
    "Thorite": 48635,
    "AlFe-Silicate_Zn": 34112,
    "Al-Oxide": 33373,
    "Fe-Sulphide_Cu": 30730,
    "W-Oxide": 28626,
    "Zn-Oxide": 27213,
    "Fe-sulphide_Pb": 26963,
    "Celestine": 26574,
    "Mn-Oxide": 25292,
    "Columbite_Mn": 23806,
    "Cu-Oxide": 19951,
    "Nb-bearing phase": 14705,
    "REE-Silicate": 13791,
    "Molybdenite": 12023
}

desired_samples_per_label = 5000
chunk_size = 100000

def dynamic_max_samples(label):
    return round(chunk_size * (desired_samples_per_label / TOTAL_SAMPLES[label]))

def save_to_file(accumulated_df, file_num):
    output_file = f"/content/drive/MyDrive/ColabNotebooks/data/combined_data_{file_num}.csv"
    accumulated_df.to_csv(output_file, index=False)
    return file_num + 1

def process_chunk(chunk, label_counts):
    samples_to_add = []
    for label in LABELS:
        if label_counts[label] >= desired_samples_per_label:
            continue
        label_rows = chunk[chunk['Mineral Phase'] == label]
        max_samples_for_label = min(dynamic_max_samples(label), desired_samples_per_label - label_counts[label])
        samples = label_rows.sample(n=min(max_samples_for_label, len(label_rows)), replace=False)
        samples_to_add.extend(samples.to_dict('records'))
        label_counts[label] += len(samples)
    return samples_to_add

accumulated_data = []
label_counts = {label: 0 for label in LABELS}
file_num = 1

with zipfile.ZipFile(zip_file_path, 'r') as z:
    csv_files = [f for f in z.namelist() if f.endswith(".csv")]

    # Find the starting file within the list.
    starting_file = next((file for file in csv_files if "Group8_0001.csv" in file), None)
    if starting_file:
        csv_files.remove(starting_file)
        random.shuffle(csv_files)
        csv_files.insert(0, starting_file)
    else:
        print("Warning: Group8_0001.csv not found in the archive. Processing in random order.")
        random.shuffle(csv_files)

    for idx, file_name in enumerate(csv_files):
        print(f"Processing file {idx+1}/{len(csv_files)}: {file_name}")

        previous_counts = label_counts.copy()

        with z.open(file_name) as file:
            chunk_iter = pd.read_csv(file, chunksize=chunk_size)
            for chunk in chunk_iter:
                accumulated_data.extend(process_chunk(chunk, label_counts))

                if len(accumulated_data) >= 2000:
                    accumulated_df = pd.DataFrame(accumulated_data)
                    file_num = save_to_file(accumulated_df, file_num)
                    accumulated_data = []
                    del accumulated_df
                    gc.collect()

                if all(count >= desired_samples_per_label for count in label_counts.values()):
                    break

            # Additional clean-up after each file
            del chunk_iter
            gc.collect()

            for label, count in label_counts.items():
                if previous_counts[label] != count:
                    print(f"Gathered {count} samples for label: {label}")

            if all(count >= desired_samples_per_label for count in label_counts.values()):
                break

if accumulated_data:
    accumulated_df = pd.DataFrame(accumulated_data)
    save_to_file(accumulated_df, file_num)
    del accumulated_df
    gc.collect()

print("Processing completed.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Gathered 861 samples for label: Al-Oxide
# Processing file 200/8327: CH Counts Data/Group8_0317.csv
# Gathered 4799 samples for label: Fe-Oxide
# Gathered 4714 samples for label: Barite
# Gathered 3468 samples for label: Leucoxene
# Gathered 974 samples for label: Carbonate
# Gathered 640 samples for label: Mn-Oxide
# Processing file 201/8327: CH Counts Data/Group8_6588.csv
# Gathered 4823 samples for label: Fe-Oxide
# Gathered 3474 samples for label: Leucoxene
# Gathered 2763 samples for label: AlCa-Silicate
# Gathered 1992 samples for label: Apatite
# Gathered 641 samples for label: Mn-Oxide
# Processing file 202/8327: CH Counts Data/Group8_2183.csv
# Gathered 4847 samples for label: Fe-Oxide
# Processing file 203/8327: CH Counts Data/Group8_7888.csv
# Gathered 4871 samples for label: Fe-Oxide
# Gathered 3476 samples for label: Leucoxene
# Gathered 2851 samples for label: AlCa-Silicate
# Gathered 1994 samples for label: Apatite
# Gathered 862 samples for label: Al-Oxide
# Processing file 204/8327: CH Counts Data/Group8_5956.csv
# Gathered 4895 samples for label: Fe-Oxide
# Gathered 4715 samples for label: Barite
# Gathered 3485 samples for label: Leucoxene
# Gathered 2859 samples for label: AlCa-Silicate
# Gathered 715 samples for label: AlFe-Silicate_Zn
# Gathered 869 samples for label: Al-Oxide
# Gathered 324 samples for label: REE-Silicate
# Processing file 205/8327: CH Counts Data/Group8_4596.csv
# Gathered 4919 samples for label: Fe-Oxide
# Processing file 206/8327: CH Counts Data/Group8_8126.csv
# Gathered 4943 samples for label: Fe-Oxide
# Gathered 3486 samples for label: Leucoxene
# Gathered 2863 samples for label: AlCa-Silicate
# Gathered 781 samples for label: AlFe-Silicate_Zn
# Gathered 878 samples for label: Al-Oxide
# Gathered 686 samples for label: Zn-Oxide
# Gathered 326 samples for label: REE-Silicate
# Processing file 207/8327: CH Counts Data/Group8_7876.csv
# Gathered 4967 samples for label: Fe-Oxide
# Gathered 3488 samples for label: Leucoxene
# Gathered 2933 samples for label: AlCa-Silicate
# Gathered 879 samples for label: Al-Oxide
# Gathered 328 samples for label: REE-Silicate
# Processing file 208/8327: CH Counts Data/Group8_7470.csv
# Gathered 4991 samples for label: Fe-Oxide
# Gathered 3491 samples for label: Leucoxene
# Gathered 2962 samples for label: AlCa-Silicate
# Gathered 799 samples for label: AlFe-Silicate_Zn
# Gathered 884 samples for label: Al-Oxide
# Gathered 695 samples for label: Zn-Oxide
# Processing file 209/8327: CH Counts Data/Group8_3278.csv
# Gathered 5000 samples for label: Fe-Oxide
# Gathered 3504 samples for label: Leucoxene
# Gathered 2996 samples for label: AlCa-Silicate
# Processing file 210/8327: CH Counts Data/Group8_4783.csv
# Gathered 4677 samples for label: Cassiterite
# Gathered 4771 samples for label: Barite
# Gathered 3513 samples for label: Leucoxene
# Gathered 2474 samples for label: Fe-Sulphide
# Gathered 3107 samples for label: AlCa-Silicate
# Gathered 2094 samples for label: Apatite
# Gathered 1100 samples for label: Xenotime
# Gathered 1149 samples for label: Carbonate
# Gathered 324 samples for label: Thorite
# Gathered 826 samples for label: AlFe-Silicate_Zn
# Gathered 950 samples for label: Al-Oxide
# Gathered 753 samples for label: Fe-Sulphide_Cu
# Gathered 542 samples for label: W-Oxide
# Gathered 721 samples for label: Zn-Oxide
# Gathered 597 samples for label: Fe-sulphide_Pb
# Gathered 4034 samples for label: Celestine
# Gathered 659 samples for label: Mn-Oxide
# Gathered 395 samples for label: Columbite_Mn
# Gathered 407 samples for label: Cu-Oxide
# Gathered 242 samples for label: Nb-bearing phase
# Gathered 329 samples for label: REE-Silicate
# Gathered 248 samples for label: Molybdenite
# Processing file 211/8327: CH Counts Data/Group8_3199.csv
# Gathered 3522 samples for label: Leucoxene
# Gathered 2154 samples for label: Apatite
# Gathered 1101 samples for label: Xenotime
# Gathered 827 samples for label: AlFe-Silicate_Zn
# Gathered 951 samples for label: Al-Oxide
# Processing file 212/8327: CH Counts Data/Group8_5904.csv
# Gathered 3528 samples for label: Leucoxene
# Gathered 3151 samples for label: AlCa-Silicate
# Gathered 2155 samples for label: Apatite
# Gathered 828 samples for label: AlFe-Silicate_Zn
# Gathered 952 samples for label: Al-Oxide
# Gathered 599 samples for label: Fe-sulphide_Pb
# Gathered 248 samples for label: Nb-bearing phase
# Gathered 332 samples for label: REE-Silicate
# Processing file 213/8327: CH Counts Data/Group8_3563.csv
# Gathered 4782 samples for label: Barite
# Gathered 3537 samples for label: Leucoxene
# Gathered 960 samples for label: Al-Oxide
# Gathered 660 samples for label: Mn-Oxide
# Processing file 214/8327: CH Counts Data/Group8_5737.csv
# Gathered 3545 samples for label: Leucoxene
# Gathered 2515 samples for label: Fe-Sulphide
# Gathered 3157 samples for label: AlCa-Silicate
# Gathered 2160 samples for label: Apatite
# Gathered 338 samples for label: REE-Silicate
# Processing file 215/8327: CH Counts Data/Group8_1545.csv
# Gathered 3571 samples for label: Leucoxene
# Gathered 3160 samples for label: AlCa-Silicate
# Gathered 1115 samples for label: Xenotime
# Gathered 4037 samples for label: Celestine
# Gathered 662 samples for label: Mn-Oxide
# Gathered 342 samples for label: REE-Silicate
# Processing file 216/8327: CH Counts Data/Group8_4373.csv
# Processing file 217/8327: CH Counts Data/Group8_7367.csv
# Gathered 3575 samples for label: Leucoxene
# Gathered 2517 samples for label: Fe-Sulphide
# Gathered 3179 samples for label: AlCa-Silicate
# Gathered 2167 samples for label: Apatite
# Gathered 325 samples for label: Thorite
# Gathered 834 samples for label: AlFe-Silicate_Zn
# Gathered 727 samples for label: Zn-Oxide
# Gathered 343 samples for label: REE-Silicate
# Processing file 218/8327: CH Counts Data/Group8_3590.csv
# Gathered 3600 samples for label: Leucoxene
# Processing file 219/8327: CH Counts Data/Group8_2800.csv
# Gathered 3719 samples for label: Leucoxene
# Gathered 3181 samples for label: AlCa-Silicate
# Gathered 845 samples for label: AlFe-Silicate_Zn
# Gathered 732 samples for label: Zn-Oxide
# Processing file 220/8327: CH Counts Data/Group8_2993.csv
# Processing file 221/8327: CH Counts Data/Group8_1911.csv
# Gathered 4685 samples for label: Cassiterite
# Gathered 4795 samples for label: Barite
# Gathered 3806 samples for label: Leucoxene
# Gathered 2518 samples for label: Fe-Sulphide
# Gathered 1142 samples for label: Xenotime
# Gathered 334 samples for label: Thorite
# Gathered 604 samples for label: Fe-sulphide_Pb
# Gathered 4049 samples for label: Celestine
# Gathered 668 samples for label: Mn-Oxide
# Gathered 407 samples for label: Columbite_Mn
# Gathered 257 samples for label: Nb-bearing phase
# Gathered 364 samples for label: REE-Silicate
# Processing file 222/8327: CH Counts Data/Group8_0018.csv
# Gathered 4797 samples for label: Barite
# Gathered 3807 samples for label: Leucoxene
# Gathered 610 samples for label: Fe-sulphide_Pb
# Gathered 4056 samples for label: Celestine
# Processing file 223/8327: CH Counts Data/Group8_4627.csv
# Processing file 224/8327: CH Counts Data/Group8_2884.csv
# Gathered 3191 samples for label: AlCa-Silicate
# Processing file 225/8327: CH Counts Data/Group8_3103.csv
# Gathered 3822 samples for label: Leucoxene
# Gathered 1150 samples for label: Carbonate
# Processing file 226/8327: CH Counts Data/Group8_1176.csv
# Gathered 4690 samples for label: Cassiterite
# Gathered 3836 samples for label: Leucoxene
# Gathered 2172 samples for label: Apatite
# Gathered 338 samples for label: Thorite
# Gathered 742 samples for label: Zn-Oxide
# Gathered 264 samples for label: Nb-bearing phase
# Processing file 227/8327: CH Counts Data/Group8_5043.csv
# Gathered 3838 samples for label: Leucoxene
# Gathered 3195 samples for label: AlCa-Silicate
# Gathered 848 samples for label: AlFe-Silicate_Zn
# Gathered 745 samples for label: Zn-Oxide
# Gathered 366 samples for label: REE-Silicate
# Processing file 228/8327: CH Counts Data/Group8_3115.csv
# Gathered 3843 samples for label: Leucoxene
# Processing file 229/8327: CH Counts Data/Group8_7676.csv
# Gathered 2524 samples for label: Fe-Sulphide
# Gathered 3249 samples for label: AlCa-Silicate
# Gathered 964 samples for label: Al-Oxide
# Processing file 230/8327: CH Counts Data/Group8_1717.csv
# Gathered 3845 samples for label: Leucoxene
# Gathered 367 samples for label: REE-Silicate
# Processing file 231/8327: CH Counts Data/Group8_1098.csv
# Gathered 4802 samples for label: Barite
# Gathered 3254 samples for label: AlCa-Silicate
# Gathered 849 samples for label: AlFe-Silicate_Zn
# Processing file 232/8327: CH Counts Data/Group8_8278.csv
# Gathered 4833 samples for label: Cassiterite
# Gathered 4890 samples for label: Barite
# Gathered 2580 samples for label: Fe-Sulphide
# Gathered 3377 samples for label: AlCa-Silicate
# Gathered 2211 samples for label: Apatite
# Gathered 1177 samples for label: Xenotime
# Gathered 1344 samples for label: Carbonate
# Gathered 377 samples for label: Thorite
# Gathered 861 samples for label: AlFe-Silicate_Zn
# Gathered 1035 samples for label: Al-Oxide
# Gathered 896 samples for label: Fe-Sulphide_Cu
# Gathered 603 samples for label: W-Oxide
# Gathered 784 samples for label: Zn-Oxide
# Gathered 691 samples for label: Fe-sulphide_Pb
# Gathered 4088 samples for label: Celestine
# Gathered 692 samples for label: Mn-Oxide
# Gathered 448 samples for label: Columbite_Mn
# Gathered 464 samples for label: Cu-Oxide
# Gathered 279 samples for label: Nb-bearing phase
# Gathered 278 samples for label: Molybdenite
# Processing file 233/8327: CH Counts Data/Group8_3150.csv
# Gathered 4935 samples for label: Barite
# Gathered 3870 samples for label: Leucoxene
# Gathered 1194 samples for label: Xenotime
# Gathered 766 samples for label: Mn-Oxide
# Processing file 234/8327: CH Counts Data/Group8_0262.csv
# Gathered 3871 samples for label: Leucoxene
# Processing file 235/8327: CH Counts Data/Group8_2693.csv
# Gathered 5000 samples for label: Barite
# Gathered 3915 samples for label: Leucoxene
# Gathered 2581 samples for label: Fe-Sulphide
# Gathered 924 samples for label: AlFe-Silicate_Zn
# Gathered 1051 samples for label: Al-Oxide
# Gathered 819 samples for label: Zn-Oxide
# Gathered 4097 samples for label: Celestine
# Gathered 289 samples for label: Nb-bearing phase
# Processing file 236/8327: CH Counts Data/Group8_4049.csv
# Gathered 3923 samples for label: Leucoxene
# Processing file 237/8327: CH Counts Data/Group8_0151.csv
# Gathered 3924 samples for label: Leucoxene
# Processing file 238/8327: CH Counts Data/Group8_1557.csv
# Gathered 4846 samples for label: Cassiterite
# Gathered 3934 samples for label: Leucoxene
# Gathered 382 samples for label: Thorite
# Processing file 239/8327: CH Counts Data/Group8_3842.csv
# Gathered 4867 samples for label: Cassiterite
# Gathered 4013 samples for label: Leucoxene
# Gathered 1063 samples for label: Al-Oxide
# Processing file 240/8327: CH Counts Data/Group8_3857.csv
# Gathered 4040 samples for label: Leucoxene
# Gathered 2582 samples for label: Fe-Sulphide
# Gathered 930 samples for label: AlFe-Silicate_Zn
# Gathered 1066 samples for label: Al-Oxide
# Gathered 821 samples for label: Zn-Oxide
# Gathered 779 samples for label: Mn-Oxide
# Processing file 241/8327: CH Counts Data/Group8_0800.csv
# Gathered 4886 samples for label: Cassiterite
# Gathered 4045 samples for label: Leucoxene
# Gathered 3379 samples for label: AlCa-Silicate
# Gathered 2216 samples for label: Apatite
# Gathered 1212 samples for label: Xenotime
# Gathered 399 samples for label: Thorite
# Gathered 938 samples for label: AlFe-Silicate_Zn
# Gathered 1068 samples for label: Al-Oxide
# Gathered 823 samples for label: Zn-Oxide
# Gathered 697 samples for label: Fe-sulphide_Pb
# Gathered 780 samples for label: Mn-Oxide
# Gathered 369 samples for label: REE-Silicate
# Processing file 242/8327: CH Counts Data/Group8_0546.csv
# Gathered 4901 samples for label: Cassiterite
# Gathered 4058 samples for label: Leucoxene
# Gathered 3382 samples for label: AlCa-Silicate
# Gathered 2276 samples for label: Apatite
# Gathered 1215 samples for label: Xenotime
# Gathered 405 samples for label: Thorite
# Gathered 939 samples for label: AlFe-Silicate_Zn
# Gathered 824 samples for label: Zn-Oxide
# Gathered 372 samples for label: REE-Silicate
# Processing file 243/8327: CH Counts Data/Group8_5735.csv
# Gathered 4059 samples for label: Leucoxene
# Gathered 3383 samples for label: AlCa-Silicate
# Gathered 2280 samples for label: Apatite
# Gathered 944 samples for label: AlFe-Silicate_Zn
# Gathered 452 samples for label: Columbite_Mn
# Gathered 293 samples for label: Nb-bearing phase
# Gathered 385 samples for label: REE-Silicate
# Processing file 244/8327: CH Counts Data/Group8_0850.csv
# Gathered 5000 samples for label: Cassiterite
# Gathered 4145 samples for label: Leucoxene
# Gathered 2437 samples for label: Apatite
# Gathered 1224 samples for label: Xenotime
# Gathered 1346 samples for label: Carbonate
# Gathered 413 samples for label: Thorite
# Gathered 1069 samples for label: Al-Oxide
# Gathered 839 samples for label: Zn-Oxide
# Gathered 781 samples for label: Mn-Oxide
# Gathered 302 samples for label: Nb-bearing phase
# Gathered 388 samples for label: REE-Silicate
# Processing file 245/8327: CH Counts Data/Group8_0199.csv
# Gathered 4161 samples for label: Leucoxene
# Gathered 3386 samples for label: AlCa-Silicate
# Processing file 246/8327: CH Counts Data/Group8_1398.csv
# Gathered 4165 samples for label: Leucoxene
# Gathered 3411 samples for label: AlCa-Silicate
# Gathered 1348 samples for label: Carbonate
# Gathered 4101 samples for label: Celestine
# Gathered 782 samples for label: Mn-Oxide
# Processing file 247/8327: CH Counts Data/Group8_5228.csv
# Gathered 4192 samples for label: Leucoxene
# Gathered 2585 samples for label: Fe-Sulphide
# Gathered 3414 samples for label: AlCa-Silicate
# Gathered 945 samples for label: AlFe-Silicate_Zn
# Processing file 248/8327: CH Counts Data/Group8_0662.csv
# Gathered 4292 samples for label: Leucoxene
# Gathered 2460 samples for label: Apatite
# Gathered 946 samples for label: AlFe-Silicate_Zn
# Gathered 854 samples for label: Zn-Oxide
# Processing file 249/8327: CH Counts Data/Group8_7320.csv
# Gathered 4305 samples for label: Leucoxene
# Gathered 2674 samples for label: Fe-Sulphide
# Gathered 950 samples for label: AlFe-Silicate_Zn
# Gathered 1071 samples for label: Al-Oxide
# Gathered 899 samples for label: Fe-Sulphide_Cu
# Processing file 250/8327: CH Counts Data/Group8_8042.csv
# Gathered 4306 samples for label: Leucoxene
# Gathered 3531 samples for label: AlCa-Silicate
# Gathered 2461 samples for label: Apatite
# Gathered 1079 samples for label: Al-Oxide
# Processing file 251/8327: CH Counts Data/Group8_3701.csv
# Gathered 4758 samples for label: Leucoxene
# Gathered 1352 samples for label: Carbonate
# Gathered 953 samples for label: AlFe-Silicate_Zn
# Gathered 461 samples for label: Columbite_Mn
# Gathered 319 samples for label: Nb-bearing phase
# Processing file 252/8327: CH Counts Data/Group8_5223.csv
# Gathered 4769 samples for label: Leucoxene
# Gathered 3602 samples for label: AlCa-Silicate
# Gathered 954 samples for label: AlFe-Silicate_Zn
# Gathered 390 samples for label: REE-Silicate
# Processing file 253/8327: CH Counts Data/Group8_7761.csv
# Gathered 3703 samples for label: AlCa-Silicate
# Gathered 2487 samples for label: Apatite
# Processing file 254/8327: CH Counts Data/Group8_7520.csv
# Gathered 4773 samples for label: Leucoxene
# Gathered 3733 samples for label: AlCa-Silicate
# Gathered 962 samples for label: AlFe-Silicate_Zn
# Gathered 1081 samples for label: Al-Oxide
# Gathered 855 samples for label: Zn-Oxide
# Processing file 255/8327: CH Counts Data/Group8_7197.csv
# Gathered 2695 samples for label: Fe-Sulphide
# Gathered 3734 samples for label: AlCa-Silicate
# Gathered 2497 samples for label: Apatite
# Gathered 414 samples for label: Thorite
# Gathered 981 samples for label: AlFe-Silicate_Zn
# Gathered 1087 samples for label: Al-Oxide
# Processing file 256/8327: CH Counts Data/Group8_7516.csv
# Gathered 4776 samples for label: Leucoxene
# Gathered 3744 samples for label: AlCa-Silicate
# Processing file 257/8327: CH Counts Data/Group8_7067.csv
# Gathered 2760 samples for label: Fe-Sulphide
# Gathered 3748 samples for label: AlCa-Silicate
# Gathered 2567 samples for label: Apatite
# Gathered 1096 samples for label: Al-Oxide
# Processing file 258/8327: CH Counts Data/Group8_1413.csv
# Gathered 4803 samples for label: Leucoxene
# Gathered 1059 samples for label: AlFe-Silicate_Zn
# Gathered 1108 samples for label: Al-Oxide
# Gathered 939 samples for label: Zn-Oxide
# Processing file 259/8327: CH Counts Data/Group8_6955.csv
# Gathered 4805 samples for label: Leucoxene
# Gathered 2797 samples for label: Fe-Sulphide
# Gathered 2570 samples for label: Apatite
# Gathered 1112 samples for label: Al-Oxide
# Gathered 396 samples for label: REE-Silicate
# Processing file 260/8327: CH Counts Data/Group8_7269.csv
# Gathered 3803 samples for label: AlCa-Silicate
# Gathered 2571 samples for label: Apatite
# Processing file 261/8327: CH Counts Data/Group8_5189.csv
# Gathered 4809 samples for label: Leucoxene
# Gathered 2811 samples for label: Fe-Sulphide
# Gathered 3828 samples for label: AlCa-Silicate
# Gathered 2572 samples for label: Apatite
# Gathered 1228 samples for label: Xenotime
# Gathered 901 samples for label: Fe-Sulphide_Cu
# Gathered 940 samples for label: Zn-Oxide
# Gathered 467 samples for label: Columbite_Mn
# Gathered 490 samples for label: Cu-Oxide
# Gathered 326 samples for label: Nb-bearing phase
# Gathered 406 samples for label: REE-Silicate
# Processing file 262/8327: CH Counts Data/Group8_5354.csv
# Gathered 4811 samples for label: Leucoxene
# Gathered 2863 samples for label: Fe-Sulphide
# Gathered 3832 samples for label: AlCa-Silicate
# Gathered 2580 samples for label: Apatite
# Processing file 263/8327: CH Counts Data/Group8_1986.csv
# Gathered 790 samples for label: Mn-Oxide
# Processing file 264/8327: CH Counts Data/Group8_3062.csv
# Gathered 4815 samples for label: Leucoxene
# Gathered 2867 samples for label: Fe-Sulphide
# Gathered 3836 samples for label: AlCa-Silicate
# Gathered 418 samples for label: Thorite
# Gathered 619 samples for label: W-Oxide
# Gathered 698 samples for label: Fe-sulphide_Pb
# Gathered 806 samples for label: Mn-Oxide
# Processing file 265/8327: CH Counts Data/Group8_4973.csv
# Gathered 4818 samples for label: Leucoxene
# Processing file 266/8327: CH Counts Data/Group8_0210.csv
# Gathered 4833 samples for label: Leucoxene
# Gathered 1962 samples for label: Xenotime
# Gathered 4125 samples for label: Celestine
# Gathered 809 samples for label: Mn-Oxide
# Gathered 327 samples for label: Nb-bearing phase
# Gathered 409 samples for label: REE-Silicate
# Processing file 267/8327: CH Counts Data/Group8_6841.csv
# Gathered 4909 samples for label: Leucoxene
# Gathered 2870 samples for label: Fe-Sulphide
# Gathered 1083 samples for label: AlFe-Silicate_Zn
# Gathered 1115 samples for label: Al-Oxide
# Gathered 949 samples for label: Zn-Oxide
# Gathered 810 samples for label: Mn-Oxide
# Processing file 268/8327: CH Counts Data/Group8_3769.csv
# Gathered 4910 samples for label: Leucoxene
# Gathered 811 samples for label: Mn-Oxide
# Gathered 331 samples for label: Nb-bearing phase
# Processing file 269/8327: CH Counts Data/Group8_6461.csv
# Gathered 4917 samples for label: Leucoxene
# Gathered 3923 samples for label: AlCa-Silicate
# Gathered 2582 samples for label: Apatite
# Gathered 421 samples for label: Thorite
# Gathered 1128 samples for label: Al-Oxide
# Gathered 468 samples for label: Columbite_Mn
# Gathered 337 samples for label: Nb-bearing phase
# Gathered 417 samples for label: REE-Silicate
# Processing file 270/8327: CH Counts Data/Group8_0536.csv
# Gathered 4946 samples for label: Leucoxene
# Gathered 2033 samples for label: Xenotime
# Gathered 616 samples for label: Thorite
# Processing file 271/8327: CH Counts Data/Group8_2056.csv
# Gathered 817 samples for label: Mn-Oxide
# Processing file 272/8327: CH Counts Data/Group8_4906.csv
# Gathered 4947 samples for label: Leucoxene
# Processing file 273/8327: CH Counts Data/Group8_3320.csv
# Gathered 3924 samples for label: AlCa-Silicate
# Processing file 274/8327: CH Counts Data/Group8_6687.csv
# Gathered 4952 samples for label: Leucoxene
# Gathered 3925 samples for label: AlCa-Silicate
# Processing file 275/8327: CH Counts Data/Group8_0146.csv
# Gathered 4953 samples for label: Leucoxene
# Gathered 338 samples for label: Nb-bearing phase
# Processing file 276/8327: CH Counts Data/Group8_2057.csv
# Gathered 2587 samples for label: Apatite
# Gathered 2036 samples for label: Xenotime
# Gathered 421 samples for label: REE-Silicate
# Processing file 277/8327: CH Counts Data/Group8_7016.csv
# Gathered 2871 samples for label: Fe-Sulphide
# Gathered 3928 samples for label: AlCa-Silicate
# Gathered 474 samples for label: Columbite_Mn
# Gathered 339 samples for label: Nb-bearing phase
# Gathered 427 samples for label: REE-Silicate
# Processing file 278/8327: CH Counts Data/Group8_7435.csv
# Gathered 3948 samples for label: AlCa-Silicate
# Gathered 2588 samples for label: Apatite
# Gathered 1130 samples for label: Al-Oxide
# Processing file 279/8327: CH Counts Data/Group8_5621.csv
# Gathered 4958 samples for label: Leucoxene
# Gathered 819 samples for label: Mn-Oxide
# Processing file 280/8327: CH Counts Data/Group8_2059.csv
# Processing file 281/8327: CH Counts Data/Group8_7606.csv
# Gathered 3964 samples for label: AlCa-Silicate
# Gathered 2589 samples for label: Apatite
# Gathered 617 samples for label: Thorite
# Gathered 1086 samples for label: AlFe-Silicate_Zn
# Gathered 1131 samples for label: Al-Oxide
# Gathered 438 samples for label: REE-Silicate
# Processing file 282/8327: CH Counts Data/Group8_5473.csv
# Gathered 4959 samples for label: Leucoxene
# Gathered 3984 samples for label: AlCa-Silicate
# Gathered 1088 samples for label: AlFe-Silicate_Zn
# Gathered 956 samples for label: Zn-Oxide
# Processing file 283/8327: CH Counts Data/Group8_1185.csv
# Gathered 5000 samples for label: Leucoxene
# Gathered 2094 samples for label: Xenotime
# Gathered 960 samples for label: Zn-Oxide
# Gathered 441 samples for label: REE-Silicate
# Processing file 284/8327: CH Counts Data/Group8_5441.csv
# Gathered 3986 samples for label: AlCa-Silicate
# Gathered 2593 samples for label: Apatite
# Gathered 963 samples for label: Zn-Oxide
# Processing file 285/8327: CH Counts Data/Group8_5657.csv
# Gathered 3988 samples for label: AlCa-Silicate
# Gathered 2594 samples for label: Apatite
# Processing file 286/8327: CH Counts Data/Group8_7609.csv
# Gathered 4010 samples for label: AlCa-Silicate
# Gathered 2595 samples for label: Apatite
# Gathered 1132 samples for label: Al-Oxide
# Processing file 287/8327: CH Counts Data/Group8_4241.csv
# Gathered 4021 samples for label: AlCa-Silicate
# Gathered 2601 samples for label: Apatite
# Gathered 1089 samples for label: AlFe-Silicate_Zn
# Gathered 446 samples for label: REE-Silicate
# Processing file 288/8327: CH Counts Data/Group8_2021.csv
# Gathered 4022 samples for label: AlCa-Silicate
# Gathered 1363 samples for label: Carbonate
# Gathered 1147 samples for label: Al-Oxide
# Processing file 289/8327: CH Counts Data/Group8_7611.csv
# Gathered 4042 samples for label: AlCa-Silicate
# Gathered 2602 samples for label: Apatite
# Gathered 618 samples for label: Thorite
# Gathered 1090 samples for label: AlFe-Silicate_Zn
# Gathered 1148 samples for label: Al-Oxide
# Gathered 973 samples for label: Zn-Oxide
# Processing file 290/8327: CH Counts Data/Group8_1774.csv
# Gathered 2100 samples for label: Xenotime
# Gathered 1370 samples for label: Carbonate
# Gathered 867 samples for label: Thorite
# Gathered 1150 samples for label: Al-Oxide
# Gathered 977 samples for label: Zn-Oxide
# Gathered 491 samples for label: Cu-Oxide
# Gathered 352 samples for label: Nb-bearing phase
# Processing file 291/8327: CH Counts Data/Group8_1182.csv
# Gathered 2106 samples for label: Xenotime
# Gathered 1093 samples for label: AlFe-Silicate_Zn
# Gathered 1160 samples for label: Al-Oxide
# Gathered 981 samples for label: Zn-Oxide
# Processing file 292/8327: CH Counts Data/Group8_6880.csv
# Gathered 4045 samples for label: AlCa-Silicate
# Gathered 2603 samples for label: Apatite
# Gathered 1102 samples for label: AlFe-Silicate_Zn
# Gathered 1162 samples for label: Al-Oxide
# Gathered 992 samples for label: Zn-Oxide
# Gathered 481 samples for label: Columbite_Mn
# Processing file 293/8327: CH Counts Data/Group8_2038.csv
# Gathered 2872 samples for label: Fe-Sulphide
# Gathered 1414 samples for label: Al-Oxide
# Gathered 903 samples for label: Fe-Sulphide_Cu
# Gathered 996 samples for label: Zn-Oxide
# Gathered 4131 samples for label: Celestine
# Gathered 829 samples for label: Mn-Oxide
# Processing file 294/8327: CH Counts Data/Group8_4100.csv
# Gathered 4052 samples for label: AlCa-Silicate
# Processing file 295/8327: CH Counts Data/Group8_5658.csv
# Gathered 2920 samples for label: Fe-Sulphide
# Gathered 4062 samples for label: AlCa-Silicate
# Gathered 2606 samples for label: Apatite
# Gathered 1118 samples for label: AlFe-Silicate_Zn
# Gathered 1416 samples for label: Al-Oxide
# Gathered 628 samples for label: W-Oxide
# Processing file 296/8327: CH Counts Data/Group8_7572.csv
# Gathered 3766 samples for label: Fe-Sulphide
# Gathered 4067 samples for label: AlCa-Silicate
# Gathered 2608 samples for label: Apatite
# Gathered 1121 samples for label: AlFe-Silicate_Zn
# Gathered 907 samples for label: Fe-Sulphide_Cu
# Gathered 997 samples for label: Zn-Oxide
# Gathered 447 samples for label: REE-Silicate
# Processing file 297/8327: CH Counts Data/Group8_2491.csv
# Gathered 4069 samples for label: AlCa-Silicate
# Gathered 2113 samples for label: Xenotime
# Gathered 875 samples for label: Thorite
# Gathered 830 samples for label: Mn-Oxide
# Processing file 298/8327: CH Counts Data/Group8_1091.csv
# Gathered 4087 samples for label: AlCa-Silicate
# Gathered 2609 samples for label: Apatite
# Gathered 2126 samples for label: Xenotime
# Gathered 1423 samples for label: Al-Oxide
# Gathered 835 samples for label: Mn-Oxide
# Gathered 356 samples for label: Nb-bearing phase
# Gathered 457 samples for label: REE-Silicate
# Processing file 299/8327: CH Counts Data/Group8_2891.csv
# Processing file 300/8327: CH Counts Data/Group8_2736.csv
# Processing file 301/8327: CH Counts Data/Group8_1543.csv
# Gathered 2128 samples for label: Xenotime
# Processing file 302/8327: CH Counts Data/Group8_2378.csv
# Gathered 458 samples for label: REE-Silicate
# Processing file 303/8327: CH Counts Data/Group8_6779.csv
# Gathered 4089 samples for label: AlCa-Silicate
# Gathered 1131 samples for label: AlFe-Silicate_Zn
# Processing file 304/8327: CH Counts Data/Group8_6904.csv
# Gathered 3769 samples for label: Fe-Sulphide
# Gathered 4116 samples for label: AlCa-Silicate
# Gathered 2625 samples for label: Apatite
# Gathered 2130 samples for label: Xenotime
# Gathered 1146 samples for label: AlFe-Silicate_Zn
# Gathered 1019 samples for label: Zn-Oxide
# Gathered 459 samples for label: REE-Silicate
# Processing file 305/8327: CH Counts Data/Group8_1824.csv
# Gathered 837 samples for label: Mn-Oxide
# Gathered 483 samples for label: Columbite_Mn
# Gathered 370 samples for label: Nb-bearing phase
# Gathered 463 samples for label: REE-Silicate
# Processing file 306/8327: CH Counts Data/Group8_0172.csv
# Gathered 4119 samples for label: AlCa-Silicate
# Gathered 2144 samples for label: Xenotime
# Gathered 4136 samples for label: Celestine
# Gathered 465 samples for label: REE-Silicate
# Processing file 307/8327: CH Counts Data/Group8_0847.csv
# Gathered 2638 samples for label: Apatite
# Gathered 2157 samples for label: Xenotime
# Gathered 916 samples for label: Thorite
# Gathered 1426 samples for label: Al-Oxide
# Gathered 629 samples for label: W-Oxide
# Gathered 1026 samples for label: Zn-Oxide
# Gathered 373 samples for label: Nb-bearing phase
# Gathered 476 samples for label: REE-Silicate
# Processing file 308/8327: CH Counts Data/Group8_1892.csv
# Gathered 2437 samples for label: Xenotime
# Gathered 1062 samples for label: Thorite
# Gathered 484 samples for label: Columbite_Mn
# Gathered 492 samples for label: Cu-Oxide
# Gathered 419 samples for label: Nb-bearing phase
# Gathered 479 samples for label: REE-Silicate
# Processing file 309/8327: CH Counts Data/Group8_6665.csv
# Gathered 1027 samples for label: Zn-Oxide
# Processing file 310/8327: CH Counts Data/Group8_7640.csv
# Gathered 3777 samples for label: Fe-Sulphide
# Gathered 4295 samples for label: AlCa-Silicate
# Gathered 2640 samples for label: Apatite
# Gathered 1152 samples for label: AlFe-Silicate_Zn
# Gathered 483 samples for label: REE-Silicate
# Processing file 311/8327: CH Counts Data/Group8_6917.csv
# Gathered 2642 samples for label: Apatite
# Gathered 1153 samples for label: AlFe-Silicate_Zn
# Gathered 1030 samples for label: Zn-Oxide
# Processing file 312/8327: CH Counts Data/Group8_5066.csv
# Gathered 2644 samples for label: Apatite
# Processing file 313/8327: CH Counts Data/Group8_2300.csv
# Gathered 1036 samples for label: Zn-Oxide
# Gathered 848 samples for label: Mn-Oxide
# Processing file 314/8327: CH Counts Data/Group8_2691.csv
# Gathered 3778 samples for label: Fe-Sulphide
# Gathered 1377 samples for label: Carbonate
# Gathered 1201 samples for label: AlFe-Silicate_Zn
# Gathered 1439 samples for label: Al-Oxide
# Gathered 1063 samples for label: Zn-Oxide
# Gathered 4139 samples for label: Celestine
# Gathered 420 samples for label: Nb-bearing phase
# Processing file 315/8327: CH Counts Data/Group8_1040.csv
# Gathered 4297 samples for label: AlCa-Silicate
# Gathered 2439 samples for label: Xenotime
# Gathered 1234 samples for label: AlFe-Silicate_Zn
# Gathered 1448 samples for label: Al-Oxide
# Gathered 1106 samples for label: Zn-Oxide
# Gathered 703 samples for label: Fe-sulphide_Pb
# Processing file 316/8327: CH Counts Data/Group8_2824.csv
# Gathered 484 samples for label: REE-Silicate
# Processing file 317/8327: CH Counts Data/Group8_7724.csv
# Gathered 4314 samples for label: AlCa-Silicate
# Gathered 2645 samples for label: Apatite
# Gathered 1449 samples for label: Al-Oxide
# Processing file 318/8327: CH Counts Data/Group8_5312.csv
# Gathered 4365 samples for label: AlCa-Silicate
# Gathered 1240 samples for label: AlFe-Silicate_Zn
# Processing file 319/8327: CH Counts Data/Group8_4994.csv
# Processing file 320/8327: CH Counts Data/Group8_7934.csv
# Gathered 3783 samples for label: Fe-Sulphide
# Gathered 4379 samples for label: AlCa-Silicate
# Gathered 2648 samples for label: Apatite
# Gathered 1241 samples for label: AlFe-Silicate_Zn
# Gathered 1453 samples for label: Al-Oxide
# Gathered 849 samples for label: Mn-Oxide
# Gathered 422 samples for label: Nb-bearing phase
# Processing file 321/8327: CH Counts Data/Group8_0905.csv
# Processing file 322/8327: CH Counts Data/Group8_1455.csv
# Processing file 323/8327: CH Counts Data/Group8_7797.csv
# Gathered 4430 samples for label: AlCa-Silicate
# Gathered 1458 samples for label: Al-Oxide
# Processing file 324/8327: CH Counts Data/Group8_6531.csv
# Gathered 3785 samples for label: Fe-Sulphide
# Gathered 4453 samples for label: AlCa-Silicate
# Gathered 2649 samples for label: Apatite
# Gathered 1244 samples for label: AlFe-Silicate_Zn
# Gathered 1459 samples for label: Al-Oxide
# Processing file 325/8327: CH Counts Data/Group8_2830.csv
# Gathered 485 samples for label: Columbite_Mn
# Gathered 430 samples for label: Nb-bearing phase
# Processing file 326/8327: CH Counts Data/Group8_5505.csv
# Gathered 4459 samples for label: AlCa-Silicate
# Processing file 327/8327: CH Counts Data/Group8_5201.csv
# Gathered 3816 samples for label: Fe-Sulphide
# Gathered 4479 samples for label: AlCa-Silicate
# Gathered 2652 samples for label: Apatite
# Gathered 912 samples for label: Fe-Sulphide_Cu
# Gathered 508 samples for label: Cu-Oxide
# Gathered 487 samples for label: REE-Silicate
# Processing file 328/8327: CH Counts Data/Group8_0063.csv
# Gathered 2504 samples for label: Xenotime
# Gathered 4218 samples for label: Celestine
# Processing file 329/8327: CH Counts Data/Group8_2660.csv
# Gathered 4485 samples for label: AlCa-Silicate
# Gathered 2696 samples for label: Apatite
# Gathered 864 samples for label: Mn-Oxide
# Processing file 330/8327: CH Counts Data/Group8_5834.csv
# Gathered 3819 samples for label: Fe-Sulphide
# Gathered 4512 samples for label: AlCa-Silicate
# Gathered 2699 samples for label: Apatite
# Gathered 1460 samples for label: Al-Oxide
# Processing file 331/8327: CH Counts Data/Group8_3587.csv
# Gathered 1245 samples for label: AlFe-Silicate_Zn
# Gathered 1461 samples for label: Al-Oxide
# Gathered 1113 samples for label: Zn-Oxide
# Processing file 332/8327: CH Counts Data/Group8_7145.csv
# Gathered 3829 samples for label: Fe-Sulphide
# Gathered 4516 samples for label: AlCa-Silicate
# Gathered 1251 samples for label: AlFe-Silicate_Zn
# Gathered 1462 samples for label: Al-Oxide
# Gathered 1114 samples for label: Zn-Oxide
# Processing file 333/8327: CH Counts Data/Group8_4075.csv
# Gathered 865 samples for label: Mn-Oxide
# Processing file 334/8327: CH Counts Data/Group8_1540.csv
# Gathered 2510 samples for label: Xenotime
# Gathered 1463 samples for label: Al-Oxide
# Gathered 867 samples for label: Mn-Oxide
# Processing file 335/8327: CH Counts Data/Group8_0503.csv
# Gathered 1117 samples for label: Thorite
# Gathered 706 samples for label: Fe-sulphide_Pb
# Gathered 869 samples for label: Mn-Oxide
# Gathered 492 samples for label: REE-Silicate
# Processing file 336/8327: CH Counts Data/Group8_8293.csv
# Gathered 3895 samples for label: Fe-Sulphide
# Gathered 4629 samples for label: AlCa-Silicate
# Gathered 2737 samples for label: Apatite
# Gathered 2546 samples for label: Xenotime
# Gathered 1575 samples for label: Carbonate
# Gathered 1154 samples for label: Thorite
# Gathered 1264 samples for label: AlFe-Silicate_Zn
# Gathered 1530 samples for label: Al-Oxide
# Gathered 1062 samples for label: Fe-Sulphide_Cu
# Gathered 694 samples for label: W-Oxide
# Gathered 1151 samples for label: Zn-Oxide
# Gathered 790 samples for label: Fe-sulphide_Pb
# Gathered 4249 samples for label: Celestine
# Gathered 890 samples for label: Mn-Oxide
# Gathered 534 samples for label: Columbite_Mn
# Gathered 569 samples for label: Cu-Oxide
# Gathered 450 samples for label: Nb-bearing phase
# Gathered 313 samples for label: Molybdenite
# Processing file 337/8327: CH Counts Data/Group8_2154.csv
# Gathered 893 samples for label: Mn-Oxide
# Processing file 338/8327: CH Counts Data/Group8_5490.csv
# Gathered 4653 samples for label: AlCa-Silicate
# Gathered 2738 samples for label: Apatite
# Gathered 1265 samples for label: AlFe-Silicate_Zn
# Gathered 495 samples for label: REE-Silicate
# Processing file 339/8327: CH Counts Data/Group8_1068.csv
# Gathered 4778 samples for label: AlCa-Silicate
# Gathered 2962 samples for label: Apatite
# Gathered 1165 samples for label: Thorite
# Gathered 1159 samples for label: Zn-Oxide
# Gathered 507 samples for label: REE-Silicate
# Processing file 340/8327: CH Counts Data/Group8_1966.csv
# Gathered 4781 samples for label: AlCa-Silicate
# Gathered 2609 samples for label: Xenotime
# Gathered 529 samples for label: REE-Silicate
# Processing file 341/8327: CH Counts Data/Group8_4184.csv
# Gathered 4782 samples for label: AlCa-Silicate
# Gathered 2928 samples for label: Carbonate
# Processing file 342/8327: CH Counts Data/Group8_6342.csv
# Gathered 4805 samples for label: AlCa-Silicate
# Gathered 1274 samples for label: AlFe-Silicate_Zn
# Processing file 343/8327: CH Counts Data/Group8_6176.csv
# Gathered 4003 samples for label: Fe-Sulphide
# Gathered 537 samples for label: REE-Silicate
# Processing file 344/8327: CH Counts Data/Group8_3387.csv
# Gathered 2624 samples for label: Xenotime
# Gathered 793 samples for label: Fe-sulphide_Pb
# Gathered 940 samples for label: Mn-Oxide
# Processing file 345/8327: CH Counts Data/Group8_6201.csv
# Gathered 4022 samples for label: Fe-Sulphide
# Gathered 4867 samples for label: AlCa-Silicate
# Gathered 2967 samples for label: Apatite
# Gathered 1531 samples for label: Al-Oxide
# Gathered 941 samples for label: Mn-Oxide
# Processing file 346/8327: CH Counts Data/Group8_0461.csv
# Gathered 4868 samples for label: AlCa-Silicate
# Gathered 3112 samples for label: Apatite
# Gathered 2642 samples for label: Xenotime
# Gathered 2929 samples for label: Carbonate
# Gathered 1169 samples for label: Thorite
# Gathered 1279 samples for label: AlFe-Silicate_Zn
# Gathered 1170 samples for label: Zn-Oxide
# Gathered 451 samples for label: Nb-bearing phase
# Gathered 570 samples for label: REE-Silicate
# Processing file 347/8327: CH Counts Data/Group8_4097.csv
# Gathered 2648 samples for label: Xenotime
# Gathered 571 samples for label: REE-Silicate
# Processing file 348/8327: CH Counts Data/Group8_3838.csv
# Gathered 1284 samples for label: AlFe-Silicate_Zn
# Gathered 1545 samples for label: Al-Oxide
# Gathered 1181 samples for label: Zn-Oxide
# Gathered 942 samples for label: Mn-Oxide
# Gathered 537 samples for label: Columbite_Mn
# Gathered 470 samples for label: Nb-bearing phase
# Processing file 349/8327: CH Counts Data/Group8_4540.csv
# Processing file 350/8327: CH Counts Data/Group8_5377.csv
# Gathered 4869 samples for label: AlCa-Silicate
# Gathered 3118 samples for label: Apatite
# Gathered 1216 samples for label: Zn-Oxide
# Processing file 351/8327: CH Counts Data/Group8_4491.csv
# Gathered 795 samples for label: Fe-sulphide_Pb
# Gathered 969 samples for label: Mn-Oxide
# Processing file 352/8327: CH Counts Data/Group8_5811.csv
# Gathered 4024 samples for label: Fe-Sulphide
# Gathered 4891 samples for label: AlCa-Silicate
# Gathered 3126 samples for label: Apatite
# Gathered 1285 samples for label: AlFe-Silicate_Zn
# Gathered 573 samples for label: REE-Silicate
# Processing file 353/8327: CH Counts Data/Group8_1529.csv
# Gathered 4983 samples for label: AlCa-Silicate
# Gathered 3127 samples for label: Apatite
# Gathered 543 samples for label: Columbite_Mn
# Gathered 473 samples for label: Nb-bearing phase
# Gathered 574 samples for label: REE-Silicate
# Processing file 354/8327: CH Counts Data/Group8_2537.csv
# Gathered 3128 samples for label: Apatite
# Gathered 2654 samples for label: Xenotime
# Gathered 1547 samples for label: Al-Oxide
# Gathered 971 samples for label: Mn-Oxide
# Processing file 355/8327: CH Counts Data/Group8_7671.csv
# Gathered 5000 samples for label: AlCa-Silicate
# Gathered 3130 samples for label: Apatite
# Gathered 2661 samples for label: Xenotime
# Gathered 1291 samples for label: AlFe-Silicate_Zn
# Gathered 1548 samples for label: Al-Oxide
# Gathered 1220 samples for label: Zn-Oxide
# Processing file 356/8327: CH Counts Data/Group8_6785.csv
# Processing file 357/8327: CH Counts Data/Group8_1478.csv
# Gathered 2676 samples for label: Xenotime
# Gathered 973 samples for label: Mn-Oxide
# Gathered 582 samples for label: REE-Silicate
# Processing file 358/8327: CH Counts Data/Group8_2011.csv
# Gathered 3143 samples for label: Apatite
# Gathered 1558 samples for label: Al-Oxide
# Gathered 4254 samples for label: Celestine
# Processing file 359/8327: CH Counts Data/Group8_4337.csv
# Gathered 4031 samples for label: Fe-Sulphide
# Processing file 360/8327: CH Counts Data/Group8_2147.csv
# Gathered 1559 samples for label: Al-Oxide
# Processing file 361/8327: CH Counts Data/Group8_7626.csv
# Gathered 3147 samples for label: Apatite
# Gathered 1295 samples for label: AlFe-Silicate_Zn
# Gathered 1562 samples for label: Al-Oxide
# Gathered 1223 samples for label: Zn-Oxide
# Processing file 362/8327: CH Counts Data/Group8_7717.csv
# Gathered 3148 samples for label: Apatite
# Gathered 1175 samples for label: Thorite
# Gathered 1312 samples for label: AlFe-Silicate_Zn
# Gathered 1565 samples for label: Al-Oxide
# Gathered 1225 samples for label: Zn-Oxide
# Gathered 583 samples for label: REE-Silicate
# Processing file 363/8327: CH Counts Data/Group8_7566.csv
# Gathered 4072 samples for label: Fe-Sulphide
# Gathered 3149 samples for label: Apatite
# Gathered 1182 samples for label: Thorite
# Gathered 584 samples for label: REE-Silicate
# Processing file 364/8327: CH Counts Data/Group8_3806.csv
# Gathered 1004 samples for label: Mn-Oxide
# Processing file 365/8327: CH Counts Data/Group8_0856.csv
# Gathered 3154 samples for label: Apatite
# Gathered 2679 samples for label: Xenotime
# Gathered 1314 samples for label: AlFe-Silicate_Zn
# Gathered 1570 samples for label: Al-Oxide
# Gathered 1010 samples for label: Mn-Oxide
# Processing file 366/8327: CH Counts Data/Group8_8237.csv
# Gathered 4135 samples for label: Fe-Sulphide
# Gathered 3184 samples for label: Apatite
# Gathered 2714 samples for label: Xenotime
# Gathered 3130 samples for label: Carbonate
# Gathered 1220 samples for label: Thorite
# Gathered 1331 samples for label: AlFe-Silicate_Zn
# Gathered 1631 samples for label: Al-Oxide
# Gathered 1203 samples for label: Fe-Sulphide_Cu
# Gathered 759 samples for label: W-Oxide
# Gathered 1270 samples for label: Zn-Oxide
# Gathered 880 samples for label: Fe-sulphide_Pb
# Gathered 4285 samples for label: Celestine
# Gathered 1025 samples for label: Mn-Oxide
# Gathered 592 samples for label: Columbite_Mn
# Gathered 632 samples for label: Cu-Oxide
# Gathered 492 samples for label: Nb-bearing phase
# Gathered 348 samples for label: Molybdenite
# Processing file 367/8327: CH Counts Data/Group8_0508.csv
# Gathered 2721 samples for label: Xenotime
# Gathered 1224 samples for label: Thorite
# Gathered 587 samples for label: REE-Silicate
# Processing file 368/8327: CH Counts Data/Group8_5108.csv
# Gathered 5000 samples for label: Fe-Sulphide
# Gathered 3190 samples for label: Apatite
# Gathered 1334 samples for label: AlFe-Silicate_Zn
# Gathered 1213 samples for label: Fe-Sulphide_Cu
# Gathered 1280 samples for label: Zn-Oxide
# Processing file 369/8327: CH Counts Data/Group8_1565.csv
# Gathered 2750 samples for label: Xenotime
# Gathered 4290 samples for label: Celestine
# Gathered 588 samples for label: REE-Silicate
# Processing file 370/8327: CH Counts Data/Group8_3292.csv
# Gathered 904 samples for label: Fe-sulphide_Pb
# Processing file 371/8327: CH Counts Data/Group8_0045.csv
# Gathered 4292 samples for label: Celestine
# Gathered 592 samples for label: REE-Silicate
# Processing file 372/8327: CH Counts Data/Group8_2251.csv
# Gathered 1636 samples for label: Al-Oxide
# Gathered 1050 samples for label: Mn-Oxide
# Processing file 373/8327: CH Counts Data/Group8_5628.csv
# Gathered 3191 samples for label: Apatite
# Processing file 374/8327: CH Counts Data/Group8_0104.csv
# Gathered 3154 samples for label: Carbonate
# Gathered 1176 samples for label: Mn-Oxide
# Processing file 375/8327: CH Counts Data/Group8_7475.csv
# Gathered 1338 samples for label: AlFe-Silicate_Zn
# Gathered 1641 samples for label: Al-Oxide
# Processing file 376/8327: CH Counts Data/Group8_3490.csv
# Gathered 2756 samples for label: Xenotime
# Gathered 1657 samples for label: Al-Oxide
# Gathered 1282 samples for label: Zn-Oxide
# Gathered 1177 samples for label: Mn-Oxide
# Gathered 493 samples for label: Nb-bearing phase
# Processing file 377/8327: CH Counts Data/Group8_7400.csv
# Gathered 3193 samples for label: Apatite
# Gathered 1226 samples for label: Thorite
# Gathered 1344 samples for label: AlFe-Silicate_Zn
# Gathered 1286 samples for label: Zn-Oxide
# Gathered 593 samples for label: REE-Silicate
# Processing file 378/8327: CH Counts Data/Group8_4047.csv
# Gathered 4299 samples for label: Celestine
# Gathered 496 samples for label: Nb-bearing phase
# Gathered 594 samples for label: REE-Silicate
# Processing file 379/8327: CH Counts Data/Group8_4165.csv
# Gathered 2060 samples for label: Al-Oxide
# Processing file 380/8327: CH Counts Data/Group8_1631.csv
# Gathered 1179 samples for label: Mn-Oxide
# Processing file 381/8327: CH Counts Data/Group8_6359.csv
# Gathered 3200 samples for label: Apatite
# Gathered 2757 samples for label: Xenotime
# Gathered 1231 samples for label: Thorite
# Gathered 2065 samples for label: Al-Oxide
# Gathered 600 samples for label: REE-Silicate
# Processing file 382/8327: CH Counts Data/Group8_6706.csv
# Gathered 1184 samples for label: Mn-Oxide
# Processing file 383/8327: CH Counts Data/Group8_3213.csv
# Gathered 3213 samples for label: Apatite
# Gathered 2777 samples for label: Xenotime
# Gathered 2066 samples for label: Al-Oxide
# Gathered 1185 samples for label: Mn-Oxide
# Gathered 603 samples for label: REE-Silicate
# Processing file 384/8327: CH Counts Data/Group8_3301.csv
# Processing file 385/8327: CH Counts Data/Group8_2242.csv
# Gathered 2073 samples for label: Al-Oxide
# Gathered 4316 samples for label: Celestine
# Processing file 386/8327: CH Counts Data/Group8_6901.csv
# Gathered 2783 samples for label: Xenotime
# Gathered 1365 samples for label: AlFe-Silicate_Zn
# Gathered 2081 samples for label: Al-Oxide
# Gathered 1328 samples for label: Zn-Oxide
# Processing file 387/8327: CH Counts Data/Group8_2013.csv
# Gathered 3163 samples for label: Carbonate
# Processing file 388/8327: CH Counts Data/Group8_7289.csv
# Gathered 1376 samples for label: AlFe-Silicate_Zn
# Gathered 1214 samples for label: Fe-Sulphide_Cu
# Processing file 389/8327: CH Counts Data/Group8_3165.csv
# Gathered 2787 samples for label: Xenotime
# Gathered 1382 samples for label: AlFe-Silicate_Zn
# Gathered 2082 samples for label: Al-Oxide
# Processing file 390/8327: CH Counts Data/Group8_5921.csv
# Gathered 3219 samples for label: Apatite
# Gathered 2793 samples for label: Xenotime
# Gathered 1388 samples for label: AlFe-Silicate_Zn
# Gathered 2085 samples for label: Al-Oxide
# Gathered 1230 samples for label: Fe-Sulphide_Cu
# Gathered 604 samples for label: REE-Silicate
# Processing file 391/8327: CH Counts Data/Group8_2766.csv
# Gathered 2805 samples for label: Xenotime
# Gathered 4326 samples for label: Celestine
# Gathered 498 samples for label: Nb-bearing phase
# Processing file 392/8327: CH Counts Data/Group8_4157.csv
# Processing file 393/8327: CH Counts Data/Group8_0507.csv
# Gathered 761 samples for label: W-Oxide
# Gathered 1330 samples for label: Zn-Oxide
# Processing file 394/8327: CH Counts Data/Group8_3438.csv
# Gathered 1389 samples for label: AlFe-Silicate_Zn
# Gathered 2092 samples for label: Al-Oxide
# Gathered 606 samples for label: REE-Silicate
# Processing file 395/8327: CH Counts Data/Group8_6142.csv
# Gathered 3220 samples for label: Apatite
# Gathered 1232 samples for label: Thorite
# Gathered 2093 samples for label: Al-Oxide
# Gathered 1332 samples for label: Zn-Oxide
# Gathered 499 samples for label: Nb-bearing phase
# Gathered 607 samples for label: REE-Silicate
# Processing file 396/8327: CH Counts Data/Group8_3712.csv
# Gathered 2096 samples for label: Al-Oxide
# Gathered 1340 samples for label: Zn-Oxide
# Gathered 1193 samples for label: Mn-Oxide
# Gathered 502 samples for label: Nb-bearing phase
# Processing file 397/8327: CH Counts Data/Group8_7555.csv
# Gathered 1238 samples for label: Thorite
# Gathered 609 samples for label: REE-Silicate
# Processing file 398/8327: CH Counts Data/Group8_0860.csv
# Gathered 3252 samples for label: Carbonate
# Processing file 399/8327: CH Counts Data/Group8_0767.csv
# Gathered 1198 samples for label: Mn-Oxide
# Processing file 400/8327: CH Counts Data/Group8_3714.csv
# Gathered 1211 samples for label: Mn-Oxide
# Processing file 401/8327: CH Counts Data/Group8_4898.csv
# Gathered 703 samples for label: Columbite_Mn
# Gathered 588 samples for label: Nb-bearing phase
# Processing file 402/8327: CH Counts Data/Group8_1276.csv
# Gathered 2832 samples for label: Xenotime
# Gathered 610 samples for label: REE-Silicate
# Processing file 403/8327: CH Counts Data/Group8_2113.csv
# Processing file 404/8327: CH Counts Data/Group8_4289.csv
# Gathered 2098 samples for label: Al-Oxide
# Processing file 405/8327: CH Counts Data/Group8_2572.csv
# Processing file 406/8327: CH Counts Data/Group8_2137.csv
# Gathered 2106 samples for label: Al-Oxide
# Gathered 1212 samples for label: Mn-Oxide
# Processing file 407/8327: CH Counts Data/Group8_6828.csv
# Gathered 1399 samples for label: AlFe-Silicate_Zn
# Gathered 2118 samples for label: Al-Oxide
# Gathered 1357 samples for label: Zn-Oxide
# Processing file 408/8327: CH Counts Data/Group8_1872.csv
# Gathered 2119 samples for label: Al-Oxide
# Gathered 1358 samples for label: Zn-Oxide
# Gathered 634 samples for label: Cu-Oxide
# Processing file 409/8327: CH Counts Data/Group8_2248.csv
# Gathered 716 samples for label: Columbite_Mn
# Processing file 410/8327: CH Counts Data/Group8_2096.csv
# Processing file 411/8327: CH Counts Data/Group8_7810.csv
# Gathered 3221 samples for label: Apatite
# Gathered 2833 samples for label: Xenotime
# Gathered 2120 samples for label: Al-Oxide
# Gathered 728 samples for label: Columbite_Mn
# Processing file 412/8327: CH Counts Data/Group8_0062.csv
# Gathered 2840 samples for label: Xenotime
# Gathered 1400 samples for label: AlFe-Silicate_Zn
# Gathered 1359 samples for label: Zn-Oxide
# Gathered 4349 samples for label: Celestine
# Processing file 413/8327: CH Counts Data/Group8_1614.csv
# Gathered 3423 samples for label: Apatite
# Gathered 2854 samples for label: Xenotime
# Gathered 2121 samples for label: Al-Oxide
# Gathered 615 samples for label: REE-Silicate
# Processing file 414/8327: CH Counts Data/Group8_2673.csv
# Gathered 1430 samples for label: AlFe-Silicate_Zn
# Gathered 2135 samples for label: Al-Oxide
# Gathered 1365 samples for label: Zn-Oxide
# Gathered 4357 samples for label: Celestine
# Gathered 1293 samples for label: Mn-Oxide
# ...
# Processing file 1699/8327: CH Counts Data/Group8_0619.csv
# Gathered 3181 samples for label: Nb-bearing phase
# Gathered 2454 samples for label: REE-Silicate
# Processing file 1700/8327: CH Counts Data/Group8_8284.csv
# Gathered 4883 samples for label: Columbite_Mn
# Gathered 4133 samples for label: Cu-Oxide
# Gathered 3199 samples for label: Nb-bearing phase
# Gathered 2648 samples for label: Molybdenite
# Processing file 1701/8327: CH Counts Data/Group8_2195.csv
# Gathered 3211 samples for label: Nb-bearing phase
# Processing file 1702/8327: CH Counts Data/Group8_3956.csv
# Processing file 1703/8327: CH Counts Data/Group8_0516.csv
# Processing file 1704/8327: CH Counts Data/Group8_7306.csv
# Gathered 2455 samples for label: REE-Silicate
# Processing file 1705/8327: CH Counts Data/Group8_1391.csv
# Processing file 1706/8327: CH Counts Data/Group8_5968.csv
# Processing file 1707/8327: CH Counts Data/Group8_6153.csv
# Processing file 1708/8327: CH Counts Data/Group8_5233.csv
# Gathered 2457 samples for label: REE-Silicate
# Processing file 1709/8327: CH Counts Data/Group8_6338.csv
# Gathered 2458 samples for label: REE-Silicate
# Processing file 1710/8327: CH Counts Data/Group8_7079.csv
# Gathered 2459 samples for label: REE-Silicate
# Processing file 1711/8327: CH Counts Data/Group8_5118.csv
# Processing file 1712/8327: CH Counts Data/Group8_4210.csv
# Processing file 1713/8327: CH Counts Data/Group8_7447.csv
# Processing file 1714/8327: CH Counts Data/Group8_5832.csv
# Processing file 1715/8327: CH Counts Data/Group8_6697.csv
# Processing file 1716/8327: CH Counts Data/Group8_4398.csv
# Gathered 2460 samples for label: REE-Silicate
# Processing file 1717/8327: CH Counts Data/Group8_0010.csv
# Processing file 1718/8327: CH Counts Data/Group8_4813.csv
# Gathered 4966 samples for label: Columbite_Mn
# Gathered 4258 samples for label: Cu-Oxide
# Gathered 3234 samples for label: Nb-bearing phase
# Gathered 2462 samples for label: REE-Silicate
# Gathered 2721 samples for label: Molybdenite
# Processing file 1719/8327: CH Counts Data/Group8_0430.csv
# Processing file 1720/8327: CH Counts Data/Group8_6459.csv
# Gathered 2468 samples for label: REE-Silicate
# Processing file 1721/8327: CH Counts Data/Group8_1607.csv
# Gathered 3236 samples for label: Nb-bearing phase
# Gathered 2495 samples for label: REE-Silicate
# Processing file 1722/8327: CH Counts Data/Group8_7802.csv
# Gathered 2496 samples for label: REE-Silicate
# Processing file 1723/8327: CH Counts Data/Group8_8132.csv
# Processing file 1724/8327: CH Counts Data/Group8_4769.csv
# Gathered 5000 samples for label: Columbite_Mn
# Gathered 4373 samples for label: Cu-Oxide
# Gathered 3258 samples for label: Nb-bearing phase
# Gathered 2790 samples for label: Molybdenite
# Processing file 1725/8327: CH Counts Data/Group8_4396.csv
# Processing file 1726/8327: CH Counts Data/Group8_0672.csv
# Gathered 2500 samples for label: REE-Silicate
# Processing file 1727/8327: CH Counts Data/Group8_0403.csv
# Processing file 1728/8327: CH Counts Data/Group8_7343.csv
# Processing file 1729/8327: CH Counts Data/Group8_5540.csv
# Processing file 1730/8327: CH Counts Data/Group8_1444.csv
# Gathered 2506 samples for label: REE-Silicate
# Processing file 1731/8327: CH Counts Data/Group8_3512.csv
# Processing file 1732/8327: CH Counts Data/Group8_7116.csv
# Gathered 2508 samples for label: REE-Silicate
# Processing file 1733/8327: CH Counts Data/Group8_0733.csv
# Gathered 2515 samples for label: REE-Silicate
# Processing file 1734/8327: CH Counts Data/Group8_7964.csv
# Processing file 1735/8327: CH Counts Data/Group8_0421.csv
# Gathered 2516 samples for label: REE-Silicate
# Processing file 1736/8327: CH Counts Data/Group8_6089.csv
# Processing file 1737/8327: CH Counts Data/Group8_2438.csv
# Gathered 2525 samples for label: REE-Silicate
# Processing file 1738/8327: CH Counts Data/Group8_3068.csv
# Processing file 1739/8327: CH Counts Data/Group8_5879.csv
# Gathered 2526 samples for label: REE-Silicate
# Processing file 1740/8327: CH Counts Data/Group8_1492.csv
# Gathered 3259 samples for label: Nb-bearing phase
# Gathered 2532 samples for label: REE-Silicate
# Processing file 1741/8327: CH Counts Data/Group8_6473.csv
# Processing file 1742/8327: CH Counts Data/Group8_3156.csv
# Processing file 1743/8327: CH Counts Data/Group8_0641.csv
# Gathered 2541 samples for label: REE-Silicate
# Processing file 1744/8327: CH Counts Data/Group8_8252.csv
# Gathered 4421 samples for label: Cu-Oxide
# Gathered 3279 samples for label: Nb-bearing phase
# Gathered 2825 samples for label: Molybdenite
# Processing file 1745/8327: CH Counts Data/Group8_5294.csv
# Gathered 3286 samples for label: Nb-bearing phase
# Gathered 2543 samples for label: REE-Silicate
# Processing file 1746/8327: CH Counts Data/Group8_7697.csv
# Processing file 1747/8327: CH Counts Data/Group8_0221.csv
# Gathered 3291 samples for label: Nb-bearing phase
# Gathered 2545 samples for label: REE-Silicate
# Processing file 1748/8327: CH Counts Data/Group8_7006.csv
# Processing file 1749/8327: CH Counts Data/Group8_0455.csv
# Processing file 1750/8327: CH Counts Data/Group8_2265.csv
# Processing file 1751/8327: CH Counts Data/Group8_7070.csv
# Processing file 1752/8327: CH Counts Data/Group8_4481.csv
# Gathered 2546 samples for label: REE-Silicate
# Processing file 1753/8327: CH Counts Data/Group8_4231.csv
# Processing file 1754/8327: CH Counts Data/Group8_3529.csv
# Processing file 1755/8327: CH Counts Data/Group8_4952.csv
# Gathered 3292 samples for label: Nb-bearing phase
# Gathered 2547 samples for label: REE-Silicate
# Processing file 1756/8327: CH Counts Data/Group8_1684.csv
# Processing file 1757/8327: CH Counts Data/Group8_2827.csv
# Processing file 1758/8327: CH Counts Data/Group8_7544.csv
# Gathered 2548 samples for label: REE-Silicate
# Processing file 1759/8327: CH Counts Data/Group8_7994.csv
# Gathered 2549 samples for label: REE-Silicate
# Processing file 1760/8327: CH Counts Data/Group8_2053.csv
# Processing file 1761/8327: CH Counts Data/Group8_2679.csv
# Processing file 1762/8327: CH Counts Data/Group8_3492.csv
# Gathered 3295 samples for label: Nb-bearing phase
# Processing file 1763/8327: CH Counts Data/Group8_4879.csv
# Gathered 3384 samples for label: Nb-bearing phase
# Gathered 2552 samples for label: REE-Silicate
# Processing file 1764/8327: CH Counts Data/Group8_0817.csv
# Gathered 3387 samples for label: Nb-bearing phase
# Processing file 1765/8327: CH Counts Data/Group8_0031.csv
# Processing file 1766/8327: CH Counts Data/Group8_1452.csv
# Processing file 1767/8327: CH Counts Data/Group8_8182.csv
# Gathered 3391 samples for label: Nb-bearing phase
# Processing file 1768/8327: CH Counts Data/Group8_4928.csv
# Processing file 1769/8327: CH Counts Data/Group8_6121.csv
# Gathered 2553 samples for label: REE-Silicate
# Processing file 1770/8327: CH Counts Data/Group8_3575.csv
# Processing file 1771/8327: CH Counts Data/Group8_3755.csv
# Processing file 1772/8327: CH Counts Data/Group8_1485.csv
# Processing file 1773/8327: CH Counts Data/Group8_7517.csv
# Gathered 2557 samples for label: REE-Silicate
# Processing file 1774/8327: CH Counts Data/Group8_6129.csv
# Processing file 1775/8327: CH Counts Data/Group8_7911.csv
# Processing file 1776/8327: CH Counts Data/Group8_4123.csv
# Processing file 1777/8327: CH Counts Data/Group8_6122.csv
# Processing file 1778/8327: CH Counts Data/Group8_7377.csv
# Processing file 1779/8327: CH Counts Data/Group8_1283.csv
# Gathered 2567 samples for label: REE-Silicate
# Processing file 1780/8327: CH Counts Data/Group8_6393.csv
# Processing file 1781/8327: CH Counts Data/Group8_2655.csv
# Processing file 1782/8327: CH Counts Data/Group8_3594.csv
# Gathered 3543 samples for label: Nb-bearing phase
# Gathered 2568 samples for label: REE-Silicate
# Processing file 1783/8327: CH Counts Data/Group8_0472.csv
# Processing file 1784/8327: CH Counts Data/Group8_0079.csv
# Gathered 2576 samples for label: REE-Silicate
# Processing file 1785/8327: CH Counts Data/Group8_2158.csv
# Processing file 1786/8327: CH Counts Data/Group8_4028.csv
# Gathered 3564 samples for label: Nb-bearing phase
# Gathered 2582 samples for label: REE-Silicate
# Processing file 1787/8327: CH Counts Data/Group8_1900.csv
# Gathered 3584 samples for label: Nb-bearing phase
# Gathered 2584 samples for label: REE-Silicate
# Processing file 1788/8327: CH Counts Data/Group8_4189.csv
# Processing file 1789/8327: CH Counts Data/Group8_7487.csv
# Gathered 2596 samples for label: REE-Silicate
# Processing file 1790/8327: CH Counts Data/Group8_2863.csv
# Processing file 1791/8327: CH Counts Data/Group8_3328.csv
# Gathered 2597 samples for label: REE-Silicate
# Processing file 1792/8327: CH Counts Data/Group8_1764.csv
# Gathered 3595 samples for label: Nb-bearing phase
# Gathered 2601 samples for label: REE-Silicate
# Processing file 1793/8327: CH Counts Data/Group8_4583.csv
# Processing file 1794/8327: CH Counts Data/Group8_1648.csv
# Gathered 2621 samples for label: REE-Silicate
# Processing file 1795/8327: CH Counts Data/Group8_5960.csv
# Gathered 2623 samples for label: REE-Silicate
# Processing file 1796/8327: CH Counts Data/Group8_6931.csv
# Processing file 1797/8327: CH Counts Data/Group8_0799.csv
# Processing file 1798/8327: CH Counts Data/Group8_0273.csv
# Processing file 1799/8327: CH Counts Data/Group8_1965.csv
# Processing file 1800/8327: CH Counts Data/Group8_8234.csv
# Processing file 1801/8327: CH Counts Data/Group8_5216.csv
# Gathered 2624 samples for label: REE-Silicate
# Processing file 1802/8327: CH Counts Data/Group8_2768.csv
# Processing file 1803/8327: CH Counts Data/Group8_0415.csv
# Processing file 1804/8327: CH Counts Data/Group8_1758.csv
# Gathered 3615 samples for label: Nb-bearing phase
# Gathered 2625 samples for label: REE-Silicate
# Processing file 1805/8327: CH Counts Data/Group8_6323.csv
# Gathered 2627 samples for label: REE-Silicate
# Processing file 1806/8327: CH Counts Data/Group8_2427.csv
# Processing file 1807/8327: CH Counts Data/Group8_7204.csv
# Gathered 3616 samples for label: Nb-bearing phase
# Processing file 1808/8327: CH Counts Data/Group8_2877.csv
# Processing file 1809/8327: CH Counts Data/Group8_7268.csv
# Processing file 1810/8327: CH Counts Data/Group8_3219.csv
# Processing file 1811/8327: CH Counts Data/Group8_7112.csv
# Processing file 1812/8327: CH Counts Data/Group8_5796.csv
# Processing file 1813/8327: CH Counts Data/Group8_2450.csv
# Gathered 2647 samples for label: REE-Silicate
# Processing file 1814/8327: CH Counts Data/Group8_3086.csv
# Processing file 1815/8327: CH Counts Data/Group8_1041.csv
# Processing file 1816/8327: CH Counts Data/Group8_5929.csv
# Gathered 2650 samples for label: REE-Silicate
# Processing file 1817/8327: CH Counts Data/Group8_7170.csv
# Processing file 1818/8327: CH Counts Data/Group8_7817.csv
# Gathered 2651 samples for label: REE-Silicate
# Processing file 1819/8327: CH Counts Data/Group8_2793.csv
# Processing file 1820/8327: CH Counts Data/Group8_1046.csv
# Processing file 1821/8327: CH Counts Data/Group8_7909.csv
# Gathered 2652 samples for label: REE-Silicate
# Processing file 1822/8327: CH Counts Data/Group8_7590.csv
# Processing file 1823/8327: CH Counts Data/Group8_8001.csv
# Gathered 2654 samples for label: REE-Silicate
# Processing file 1824/8327: CH Counts Data/Group8_2721.csv
# Processing file 1825/8327: CH Counts Data/Group8_4971.csv
# Processing file 1826/8327: CH Counts Data/Group8_4541.csv
# Processing file 1827/8327: CH Counts Data/Group8_6017.csv
# Processing file 1828/8327: CH Counts Data/Group8_4358.csv
# Gathered 2655 samples for label: REE-Silicate
# Processing file 1829/8327: CH Counts Data/Group8_7449.csv
# Gathered 2660 samples for label: REE-Silicate
# Processing file 1830/8327: CH Counts Data/Group8_7926.csv
# Gathered 2662 samples for label: REE-Silicate
# Processing file 1831/8327: CH Counts Data/Group8_4720.csv
# Gathered 4498 samples for label: Cu-Oxide
# Gathered 3632 samples for label: Nb-bearing phase
# Gathered 2667 samples for label: REE-Silicate
# Gathered 2896 samples for label: Molybdenite
# Processing file 1832/8327: CH Counts Data/Group8_0085.csv
# Processing file 1833/8327: CH Counts Data/Group8_5568.csv
# Gathered 2671 samples for label: REE-Silicate
# Processing file 1834/8327: CH Counts Data/Group8_0096.csv
# Gathered 2672 samples for label: REE-Silicate
# Processing file 1835/8327: CH Counts Data/Group8_2616.csv
# Gathered 2673 samples for label: REE-Silicate
# Processing file 1836/8327: CH Counts Data/Group8_6590.csv
# Processing file 1837/8327: CH Counts Data/Group8_1785.csv
# Processing file 1838/8327: CH Counts Data/Group8_6064.csv
# Processing file 1839/8327: CH Counts Data/Group8_4753.csv
# Gathered 4616 samples for label: Cu-Oxide
# Gathered 3658 samples for label: Nb-bearing phase
# Gathered 2677 samples for label: REE-Silicate
# Gathered 2967 samples for label: Molybdenite
# Processing file 1840/8327: CH Counts Data/Group8_2372.csv
# Gathered 3735 samples for label: Nb-bearing phase
# Gathered 2700 samples for label: REE-Silicate
# Processing file 1841/8327: CH Counts Data/Group8_2907.csv
# Processing file 1842/8327: CH Counts Data/Group8_0441.csv
# Gathered 2719 samples for label: REE-Silicate
# Processing file 1843/8327: CH Counts Data/Group8_0335.csv
# Processing file 1844/8327: CH Counts Data/Group8_1290.csv
# Gathered 3746 samples for label: Nb-bearing phase
# Gathered 2764 samples for label: REE-Silicate
# Processing file 1845/8327: CH Counts Data/Group8_0200.csv
# Processing file 1846/8327: CH Counts Data/Group8_5531.csv
# Gathered 2767 samples for label: REE-Silicate
# Processing file 1847/8327: CH Counts Data/Group8_4177.csv
# Processing file 1848/8327: CH Counts Data/Group8_4981.csv
# Gathered 2768 samples for label: REE-Silicate
# Processing file 1849/8327: CH Counts Data/Group8_1596.csv
# Gathered 3747 samples for label: Nb-bearing phase
# Gathered 2771 samples for label: REE-Silicate
# Processing file 1850/8327: CH Counts Data/Group8_3961.csv
# Processing file 1851/8327: CH Counts Data/Group8_5545.csv
# Gathered 3753 samples for label: Nb-bearing phase
# Processing file 1852/8327: CH Counts Data/Group8_5780.csv
# Gathered 2773 samples for label: REE-Silicate
# Processing file 1853/8327: CH Counts Data/Group8_7083.csv
# Processing file 1854/8327: CH Counts Data/Group8_3173.csv
# Processing file 1855/8327: CH Counts Data/Group8_3395.csv
# Gathered 3754 samples for label: Nb-bearing phase
# Processing file 1856/8327: CH Counts Data/Group8_3230.csv
# Processing file 1857/8327: CH Counts Data/Group8_6895.csv
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-7a619d016282> in <cell line: 88>()
#     105
# --> 106         with z.open(file_name) as file:
#     107             chunk_iter = pd.read_csv(file, chunksize=chunk_size)
#
# /usr/lib/python3.10/zipfile.py in open(self, name, mode, pwd, force_zip64)
#    1531             # Skip the file header:
# -> 1532             fheader = zef_file.read(sizeFileHeader)
#    1533             if len(fheader) != sizeFileHeader:
#
# /usr/lib/python3.10/zipfile.py in read(self, n)
#     746             self._file.seek(self._pos)
# --> 747             data = self._file.read(n)
#     748             self._pos = self._file.tell()
#
# OSError: [Errno 107] Transport endpoint is not connected
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-7a619d016282> in <cell line: 88>()
#      86 file_num = 1
#      87
# ---> 88 with zipfile.ZipFile(zip_file_path, 'r') as z:
#      89     csv_files = [f for f in z.namelist() if f.endswith(".csv")]
#      90
#
# /usr/lib/python3.10/zipfile.py in __exit__(self, type, value, traceback)
#    1310
#    1311     def __exit__(self, type, value, traceback):
# -> 1312         self.close()
#    1313
#    1314     def __repr__(self):
#
# /usr/lib/python3.10/zipfile.py in close(self)
#    1841             fp = self.fp
#    1842             self.fp = None
# -> 1843             self._fpclose(fp)
#    1844
#    1845     def _write_end_record(self):
#
# /usr/lib/python3.10/zipfile.py in _fpclose(self, fp)
#    1941         self._fileRefCnt -= 1
#    1942         if not self._fileRefCnt and not self._filePassed:
# -> 1943             fp.close()
#    1944
#    1945
#
# OSError: [Errno 107] Transport endpoint is not connected

# %%
import pandas as pd


#Concatanate output files

# Specify Input Files
input_folder = '/content/drive/MyDrive/ColabNotebooks/data/'
input_files = [f"{input_folder}combined_data_{file_num}.csv" for file_num in range(1, 75)]

# Concatenate CSVs
concatenated_df = pd.concat([pd.read_csv(file) for file in input_files], ignore_index=True)

# Save Concatenated Data
output_file = f"{input_folder}concatenated_data.csv"
concatenated_df.to_csv(output_file, index=False)

# %%
import pandas as pd

# Specify the path to the concatenated CSV file
concatenated_file_path = '/content/drive/MyDrive/ColabNotebooks/data/concatenated_data_1000.csv'

# Read the concatenated CSV file into a DataFrame
concatenated_df = pd.read_csv(concatenated_file_path)

# Calculate and print the summary of label counts
label_counts = concatenated_df['Mineral Phase'].value_counts()
print(label_counts)
# Out:
# Ilmenite            1000
# Xenotime            1000
# Al-Silicate         1000
# Al-Oxide            1000
# Fe-Sulphide         1000
# Barite              1000
# Carbonate           1000
# Fe-sulphide_Pb      1000
# Cassiterite         1000
# Apatite             1000
# Thorite             1000
# Fe-Sulphide_Cu      1000
# Columbite_Mn        1000
# Cu-Oxide            1000
# Celestine           1000
# W-Oxide             1000
# AlFe-Silicate       1000
# Chromite            1000
# Zircon              1000
# Mn-Oxide            1000
# Fe-Silicate         1000
# Quartz              1000
# AlK-Silicate        1000
# AlFe-Silicate_Zn    1000
# Zn-Oxide            1000
# Rutile              1000
# Molybdenite         1000
# Titanite            1000
# AlMn-Silicate       1000
# Monazite            1000
# Leucoxene           1000
# AlCa-Silicate       1000
# Amphibole            945
# Epidote              903
# Nb-bearing phase     889
# REE-Silicate         839
# Name: Mineral Phase, dtype: int64

# %%
# Calculate the total number of unique labels
total_labels = concatenated_df['Mineral Phase'].nunique()

# Print the total number of unique labels
print("Total Unique Labels:", total_labels)
# Out:
# Total Unique Labels: 38
