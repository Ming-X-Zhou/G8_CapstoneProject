# %%
import csv
import random
import os
import pandas as pd

raw_data_folder = "E:\CP_raw_data"
processed_data_folder = "E:\CP_processed_data"

#Testing
LABELS = ["AlFe-Silicate", "Fe-Sulphide"]

# %%
LABELS = [ 
    "Fe-Oxide", "Background", "Ilmenite", "Epidote", "Amphibole", 
    "AlFe-Silicate", "Fe-Silicate", "Titanite", "AlMn-Silicate", 
    "Rutile", "Zircon", "Monazite", "Quartz", "Cassiterite", 
    "AlK-Silicate", "Barite", "Al-Silicate", "Chromite", 
    "Leucoxene", "Fe-Sulphide", "AlCa-Silicate", "Apatite", 
    "Xenotime", "Carbonate", "Thorite", "AlFe-Silicate_Zn", 
    "Al-Oxide", "Fe-Sulphide_Cu", "W-Oxide", "Zn-Oxide", 
    "Fe-sulphide_Pb", "Celestine", "Mn-Oxide", "Columbite_Mn", 
    "Cu-Oxide", "Nb-bearing phase", "REE-Silicate", "Molybdenite"]

# %%
big_file_threshold = 200 * 1024 * 1024  # 100,000 KB in bytes
csv.field_size_limit(1000000000)  # or another appropriate limit

header_columns = ["x", "y", "yinv"] + [f"CH_{i}" for i in range(1, 4097)] + ["Sum", "Mineral Phase"]

def is_valid_row(row, label):
    return len(row) == 4101

for label in LABELS:
    raw_data_path = os.path.join(raw_data_folder, f"{label}_samples.csv")
    processed_data_path = os.path.join(processed_data_folder, f"{label}.csv")
    
    if not os.path.exists(raw_data_path):
        print(f"[ERROR] No file found for label: {label}")
        continue

    # Determine the chunk size and total sample size based on file size
    file_size = os.path.getsize(raw_data_path)
    chunk_size = file_size // 10

    if file_size > big_file_threshold:
        total_samples = 22000
        samples_per_chunk = total_samples // 10
    else:
        total_samples = 12000
        samples_per_chunk = total_samples // 10

    print(f"\n[INFO] Starting processing for label: {label}")
    print(f"[INFO] File size: {file_size / (1024*1024):.2f} MB")
    print(f"[INFO] Chunk size: {chunk_size / (1024*1024):.2f} MB")
    
    total_valid_rows = 0
    total_sampled_rows = 0
    chunk_count = 0

    with open(raw_data_path, 'r') as infile, open(processed_data_path, 'w', newline='') as outfile:
        reader = csv.reader(infile)
        writer = csv.writer(outfile)

        header = next(reader)
        writer.writerow(header_columns)  # Write the header

        valid_rows = []
        read_size = 0
        end_of_file = False

        for row in reader:
            read_size += sum(len(field) for field in row) + len(row)
            
            if is_valid_row(row, label):
                valid_rows.append(row)
                
            if read_size >= chunk_size or end_of_file:
                chunk_count += 1
                current_sample_size = min(samples_per_chunk, len(valid_rows))
                sampled_rows = random.sample(valid_rows, current_sample_size)

                writer.writerows(sampled_rows)  # Write sampled rows chunk by chunk
                
                total_valid_rows += len(valid_rows)
                total_sampled_rows += len(sampled_rows)

                print(f"[INFO] Chunk {chunk_count}: Sampled {len(sampled_rows)} out of {len(valid_rows)} valid rows.")
                
                valid_rows.clear()
                read_size = 0

                # Stop sampling if we've reached our total sampling goal
                if total_sampled_rows >= total_samples:
                    break

            if read_size >= chunk_size:
                end_of_file = True
        
        # Handle the case where the total number of rows is below 10,000
        if total_valid_rows < 10000:
            print(f"[INFO] File has less than 10,000 valid rows. Saving all {total_valid_rows} valid rows.")
            writer.writerows(valid_rows)

    print(f"[SUMMARY] For label {label}: out of {total_valid_rows} valid rows, {total_sampled_rows} rows were sampled.")
    print(f"[INFO] Sampled data saved for label: {label}\n")

print("[DONE] All files processed.")
# Out:
# [INFO] Starting processing for label: Fe-Oxide
# [INFO] File size: 20929.98 MB
# [INFO] Chunk size: 2093.00 MB
# [INFO] Chunk 1: Sampled 2200 out of 222341 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 234467 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 211133 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 206865 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 204500 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 243593 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 236508 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 229893 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 229777 valid rows.
# [SUMMARY] For label Fe-Oxide: out of 2019077 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Fe-Oxide
#
#
# [INFO] Starting processing for label: Background
# [INFO] File size: 11009.23 MB
# [INFO] Chunk size: 1100.92 MB
# [INFO] Chunk 1: Sampled 2200 out of 126219 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 129840 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 120996 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 124834 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 132033 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 131432 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 130482 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 127836 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 134945 valid rows.
# [SUMMARY] For label Background: out of 1158617 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Background
#
#
# [INFO] Starting processing for label: Ilmenite
# [INFO] File size: 8123.39 MB
# [INFO] Chunk size: 812.34 MB
# [INFO] Chunk 1: Sampled 2200 out of 72763 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 75427 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 76776 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 54030 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 80809 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 76356 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 72541 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 75225 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 79514 valid rows.
# [SUMMARY] For label Ilmenite: out of 663441 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Ilmenite
#
#
# [INFO] Starting processing for label: Epidote
# [INFO] File size: 4709.41 MB
# [INFO] Chunk size: 470.94 MB
# [INFO] Chunk 1: Sampled 2200 out of 52778 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 52506 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 51325 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 50453 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 56665 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 52861 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 49292 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 55234 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 52529 valid rows.
# [SUMMARY] For label Epidote: out of 473643 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Epidote
#
#
# [INFO] Starting processing for label: Amphibole
# [INFO] File size: 4022.01 MB
# [INFO] Chunk size: 402.20 MB
# [INFO] Chunk 1: Sampled 2200 out of 34267 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 43958 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 40758 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 40009 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 46605 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 44902 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 34887 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 43468 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 43679 valid rows.
# [SUMMARY] For label Amphibole: out of 372533 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Amphibole
#
#
# [INFO] Starting processing for label: AlFe-Silicate
# [INFO] File size: 4166.87 MB
# [INFO] Chunk size: 416.69 MB
# [INFO] Chunk 1: Sampled 2200 out of 39941 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 41013 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 44591 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 34415 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 38855 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 42059 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 42929 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 45646 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 44550 valid rows.
# [SUMMARY] For label AlFe-Silicate: out of 373999 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: AlFe-Silicate
#
#
# [INFO] Starting processing for label: Fe-Silicate
# [INFO] File size: 1686.48 MB
# [INFO] Chunk size: 168.65 MB
# [INFO] Chunk 1: Sampled 2200 out of 18099 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 18682 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 18904 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 15189 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 17126 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 17972 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 18364 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 17782 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 17809 valid rows.
# [SUMMARY] For label Fe-Silicate: out of 159927 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Fe-Silicate
#
#
# [INFO] Starting processing for label: Titanite
# [INFO] File size: 1413.04 MB
# [INFO] Chunk size: 141.30 MB
# [INFO] Chunk 1: Sampled 2200 out of 13981 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 13605 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 14953 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 16005 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 15658 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 12336 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 13091 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 16903 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 15740 valid rows.
# [SUMMARY] For label Titanite: out of 132272 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Titanite
#
#
# [INFO] Starting processing for label: AlMn-Silicate
# [INFO] File size: 1314.56 MB
# [INFO] Chunk size: 131.46 MB
# [INFO] Chunk 1: Sampled 2200 out of 15171 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 13300 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 14321 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 14900 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 11824 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 15548 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 14707 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 14410 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 15020 valid rows.
# [SUMMARY] For label AlMn-Silicate: out of 129201 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: AlMn-Silicate
#
#
# [INFO] Starting processing for label: Rutile
# [INFO] File size: 880.31 MB
# [INFO] Chunk size: 88.03 MB
# [INFO] Chunk 1: Sampled 2200 out of 10504 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 10836 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 9599 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 8333 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 9835 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 9967 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 10977 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 10623 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 10652 valid rows.
# [SUMMARY] For label Rutile: out of 91326 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Rutile
#
#
# [INFO] Starting processing for label: Zircon
# [INFO] File size: 611.48 MB
# [INFO] Chunk size: 61.15 MB
# [INFO] Chunk 1: Sampled 2200 out of 7534 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 7511 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 5127 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 7121 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 7022 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 7558 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 7585 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 7360 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 7437 valid rows.
# [SUMMARY] For label Zircon: out of 64255 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Zircon
#
#
# [INFO] Starting processing for label: Monazite
# [INFO] File size: 335.40 MB
# [INFO] Chunk size: 33.54 MB
# [INFO] Chunk 1: Sampled 2200 out of 3953 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 3536 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 3265 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 3889 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 3859 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 3728 valid rows.
# [INFO] Chunk 7: Sampled 1819 out of 1819 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 3747 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 3969 valid rows.
# [SUMMARY] For label Monazite: out of 31765 valid rows, 19419 rows were sampled.
# [INFO] Sampled data saved for label: Monazite
#
#
# [INFO] Starting processing for label: Quartz
# [INFO] File size: 351.71 MB
# [INFO] Chunk size: 35.17 MB
# [INFO] Chunk 1: Sampled 2200 out of 4165 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 4320 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 4160 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 4219 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 4220 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 4352 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 3788 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 3950 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 4256 valid rows.
# [SUMMARY] For label Quartz: out of 37430 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Quartz
#
#
# [INFO] Starting processing for label: Cassiterite
# [INFO] File size: 405.78 MB
# [INFO] Chunk size: 40.58 MB
# [INFO] Chunk 1: Sampled 2200 out of 5063 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 5127 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 5104 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 5064 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 5127 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 5129 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 4796 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 5125 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 5127 valid rows.
# [SUMMARY] For label Cassiterite: out of 45662 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Cassiterite
#
#
# [INFO] Starting processing for label: AlK-Silicate
# [INFO] File size: 265.28 MB
# [INFO] Chunk size: 26.53 MB
# [INFO] Chunk 1: Sampled 2200 out of 3030 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 3168 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 3144 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 3055 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 2648 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 3238 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 2788 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 3054 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 3063 valid rows.
# [SUMMARY] For label AlK-Silicate: out of 27188 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: AlK-Silicate
#
#
# [INFO] Starting processing for label: Barite
# [INFO] File size: 371.38 MB
# [INFO] Chunk size: 37.14 MB
# [INFO] Chunk 1: Sampled 2200 out of 4532 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 4484 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 4670 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 4647 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 4596 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 4581 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 4663 valid rows.
# [INFO] Chunk 8: Sampled 1334 out of 1334 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 2354 valid rows.
# [SUMMARY] For label Barite: out of 35861 valid rows, 18934 rows were sampled.
# [INFO] Sampled data saved for label: Barite
#
#
# [INFO] Starting processing for label: Al-Silicate
# [INFO] File size: 265.24 MB
# [INFO] Chunk size: 26.52 MB
# [INFO] Chunk 1: Sampled 2200 out of 3218 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 3256 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 3120 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 2882 valid rows.
# [INFO] Chunk 5: Sampled 2200 out of 3178 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 3002 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 3195 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 3152 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 3288 valid rows.
# [SUMMARY] For label Al-Silicate: out of 28291 valid rows, 19800 rows were sampled.
# [INFO] Sampled data saved for label: Al-Silicate
#
#
# [INFO] Starting processing for label: Chromite
# [INFO] File size: 221.87 MB
# [INFO] Chunk size: 22.19 MB
# [INFO] Chunk 1: Sampled 2200 out of 2693 valid rows.
# [INFO] Chunk 2: Sampled 2200 out of 2666 valid rows.
# [INFO] Chunk 3: Sampled 2200 out of 2711 valid rows.
# [INFO] Chunk 4: Sampled 2200 out of 2531 valid rows.
# [INFO] Chunk 5: Sampled 2045 out of 2045 valid rows.
# [INFO] Chunk 6: Sampled 2200 out of 2762 valid rows.
# [INFO] Chunk 7: Sampled 2200 out of 2748 valid rows.
# [INFO] Chunk 8: Sampled 2200 out of 2757 valid rows.
# [INFO] Chunk 9: Sampled 2200 out of 2681 valid rows.
# [SUMMARY] For label Chromite: out of 23594 valid rows, 19645 rows were sampled.
# [INFO] Sampled data saved for label: Chromite
#
#
# [INFO] Starting processing for label: Leucoxene
# [INFO] File size: 141.52 MB
# [INFO] Chunk size: 14.15 MB
# [INFO] Chunk 1: Sampled 1200 out of 1510 valid rows.
# [INFO] Chunk 2: Sampled 1200 out of 1689 valid rows.
# [INFO] Chunk 3: Sampled 1200 out of 1426 valid rows.
# [INFO] Chunk 4: Sampled 1200 out of 1334 valid rows.
# [INFO] Chunk 5: Sampled 1200 out of 1615 valid rows.
# [INFO] Chunk 6: Sampled 1200 out of 1587 valid rows.
# [INFO] Chunk 7: Sampled 1200 out of 1629 valid rows.
# [INFO] Chunk 8: Sampled 1200 out of 1502 valid rows.
# [INFO] Chunk 9: Sampled 1200 out of 1483 valid rows.
# [SUMMARY] For label Leucoxene: out of 13775 valid rows, 10800 rows were sampled.
# [INFO] Sampled data saved for label: Leucoxene
#
#
# [INFO] Starting processing for label: Fe-Sulphide
# [INFO] File size: 114.66 MB
# [INFO] Chunk size: 11.47 MB
# [INFO] Chunk 1: Sampled 1200 out of 1372 valid rows.
# [INFO] Chunk 2: Sampled 773 out of 773 valid rows.
# [INFO] Chunk 3: Sampled 1200 out of 1320 valid rows.
# [INFO] Chunk 4: Sampled 1200 out of 1444 valid rows.
# [INFO] Chunk 5: Sampled 1200 out of 1434 valid rows.
# [INFO] Chunk 6: Sampled 1200 out of 1407 valid rows.
# [INFO] Chunk 7: Sampled 827 out of 827 valid rows.
# [INFO] Chunk 8: Sampled 1200 out of 1268 valid rows.
# [INFO] Chunk 9: Sampled 1140 out of 1140 valid rows.
# [SUMMARY] For label Fe-Sulphide: out of 10985 valid rows, 9940 rows were sampled.
# [INFO] Sampled data saved for label: Fe-Sulphide
#
#
# [INFO] Starting processing for label: AlCa-Silicate
# [INFO] File size: 124.82 MB
# [INFO] Chunk size: 12.48 MB
# [INFO] Chunk 1: Sampled 1200 out of 1451 valid rows.
# [INFO] Chunk 2: Sampled 1200 out of 1326 valid rows.
# [INFO] Chunk 3: Sampled 1200 out of 1488 valid rows.
# [INFO] Chunk 4: Sampled 1200 out of 1299 valid rows.
# [INFO] Chunk 5: Sampled 1200 out of 1492 valid rows.
# [INFO] Chunk 6: Sampled 1200 out of 1490 valid rows.
# [INFO] Chunk 7: Sampled 1200 out of 1302 valid rows.
# [INFO] Chunk 8: Sampled 1200 out of 1234 valid rows.
# [INFO] Chunk 9: Sampled 1200 out of 1481 valid rows.
# [SUMMARY] For label AlCa-Silicate: out of 12563 valid rows, 10800 rows were sampled.
# [INFO] Sampled data saved for label: AlCa-Silicate
#
#
# [INFO] Starting processing for label: Apatite
# [INFO] File size: 85.33 MB
# [INFO] Chunk size: 8.53 MB
# [INFO] Chunk 1: Sampled 1045 out of 1045 valid rows.
# [INFO] Chunk 2: Sampled 1022 out of 1022 valid rows.
# [INFO] Chunk 3: Sampled 1004 out of 1004 valid rows.
# [INFO] Chunk 4: Sampled 1047 out of 1047 valid rows.
# [INFO] Chunk 5: Sampled 1072 out of 1072 valid rows.
# [INFO] Chunk 6: Sampled 998 out of 998 valid rows.
# [INFO] Chunk 7: Sampled 1020 out of 1020 valid rows.
# [INFO] Chunk 8: Sampled 1077 out of 1077 valid rows.
# [INFO] Chunk 9: Sampled 987 out of 987 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 9272 valid rows.
# [SUMMARY] For label Apatite: out of 9272 valid rows, 9272 rows were sampled.
# [INFO] Sampled data saved for label: Apatite
#
#
# [INFO] Starting processing for label: Xenotime
# [INFO] File size: 72.03 MB
# [INFO] Chunk size: 7.20 MB
# [INFO] Chunk 1: Sampled 894 out of 894 valid rows.
# [INFO] Chunk 2: Sampled 887 out of 887 valid rows.
# [INFO] Chunk 3: Sampled 889 out of 889 valid rows.
# [INFO] Chunk 4: Sampled 744 out of 744 valid rows.
# [INFO] Chunk 5: Sampled 870 out of 870 valid rows.
# [INFO] Chunk 6: Sampled 857 out of 857 valid rows.
# [INFO] Chunk 7: Sampled 647 out of 647 valid rows.
# [INFO] Chunk 8: Sampled 900 out of 900 valid rows.
# [INFO] Chunk 9: Sampled 895 out of 895 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 7583 valid rows.
# [SUMMARY] For label Xenotime: out of 7583 valid rows, 7583 rows were sampled.
# [INFO] Sampled data saved for label: Xenotime
#
#
# [INFO] Starting processing for label: Carbonate
# [INFO] File size: 70.01 MB
# [INFO] Chunk size: 7.00 MB
# [INFO] Chunk 1: Sampled 885 out of 885 valid rows.
# [INFO] Chunk 2: Sampled 885 out of 885 valid rows.
# [INFO] Chunk 3: Sampled 885 out of 885 valid rows.
# [INFO] Chunk 4: Sampled 885 out of 885 valid rows.
# [INFO] Chunk 5: Sampled 872 out of 872 valid rows.
# [INFO] Chunk 6: Sampled 885 out of 885 valid rows.
# [INFO] Chunk 7: Sampled 884 out of 884 valid rows.
# [INFO] Chunk 8: Sampled 885 out of 885 valid rows.
# [INFO] Chunk 9: Sampled 886 out of 886 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 7952 valid rows.
# [SUMMARY] For label Carbonate: out of 7952 valid rows, 7952 rows were sampled.
# [INFO] Sampled data saved for label: Carbonate
#
#
# [INFO] Starting processing for label: Thorite
# [INFO] File size: 36.51 MB
# [INFO] Chunk size: 3.65 MB
# [INFO] Chunk 1: Sampled 456 out of 456 valid rows.
# [INFO] Chunk 2: Sampled 447 out of 447 valid rows.
# [INFO] Chunk 3: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 4: Sampled 457 out of 457 valid rows.
# [INFO] Chunk 5: Sampled 450 out of 450 valid rows.
# [INFO] Chunk 6: Sampled 458 out of 458 valid rows.
# [INFO] Chunk 7: Sampled 458 out of 458 valid rows.
# [INFO] Chunk 8: Sampled 443 out of 443 valid rows.
# [INFO] Chunk 9: Sampled 425 out of 425 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 4043 valid rows.
# [SUMMARY] For label Thorite: out of 4043 valid rows, 4043 rows were sampled.
# [INFO] Sampled data saved for label: Thorite
#
#
# [INFO] Starting processing for label: AlFe-Silicate_Zn
# [INFO] File size: 33.72 MB
# [INFO] Chunk size: 3.37 MB
# [INFO] Chunk 1: Sampled 330 out of 330 valid rows.
# [INFO] Chunk 2: Sampled 361 out of 361 valid rows.
# [INFO] Chunk 3: Sampled 382 out of 382 valid rows.
# [INFO] Chunk 4: Sampled 393 out of 393 valid rows.
# [INFO] Chunk 5: Sampled 286 out of 286 valid rows.
# [INFO] Chunk 6: Sampled 395 out of 395 valid rows.
# [INFO] Chunk 7: Sampled 405 out of 405 valid rows.
# [INFO] Chunk 8: Sampled 333 out of 333 valid rows.
# [INFO] Chunk 9: Sampled 414 out of 414 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 3299 valid rows.
# [SUMMARY] For label AlFe-Silicate_Zn: out of 3299 valid rows, 3299 rows were sampled.
# [INFO] Sampled data saved for label: AlFe-Silicate_Zn
#
#
# [INFO] Starting processing for label: Al-Oxide
# [INFO] File size: 32.72 MB
# [INFO] Chunk size: 3.27 MB
# [INFO] Chunk 1: Sampled 334 out of 334 valid rows.
# [INFO] Chunk 2: Sampled 361 out of 361 valid rows.
# [INFO] Chunk 3: Sampled 407 out of 407 valid rows.
# [INFO] Chunk 4: Sampled 395 out of 395 valid rows.
# [INFO] Chunk 5: Sampled 390 out of 390 valid rows.
# [INFO] Chunk 6: Sampled 414 out of 414 valid rows.
# [INFO] Chunk 7: Sampled 406 out of 406 valid rows.
# [INFO] Chunk 8: Sampled 398 out of 398 valid rows.
# [INFO] Chunk 9: Sampled 414 out of 414 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 3519 valid rows.
# [SUMMARY] For label Al-Oxide: out of 3519 valid rows, 3519 rows were sampled.
# [INFO] Sampled data saved for label: Al-Oxide
#
#
# [INFO] Starting processing for label: Fe-Sulphide_Cu
# [INFO] File size: 39.61 MB
# [INFO] Chunk size: 3.96 MB
# [INFO] Chunk 1: Sampled 480 out of 480 valid rows.
# [INFO] Chunk 2: Sampled 497 out of 497 valid rows.
# [INFO] Chunk 3: Sampled 495 out of 495 valid rows.
# [INFO] Chunk 4: Sampled 488 out of 488 valid rows.
# [INFO] Chunk 5: Sampled 497 out of 497 valid rows.
# [INFO] Chunk 6: Sampled 497 out of 497 valid rows.
# [INFO] Chunk 7: Sampled 494 out of 494 valid rows.
# [INFO] Chunk 8: Sampled 497 out of 497 valid rows.
# [INFO] Chunk 9: Sampled 497 out of 497 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 4442 valid rows.
# [SUMMARY] For label Fe-Sulphide_Cu: out of 4442 valid rows, 4442 rows were sampled.
# [INFO] Sampled data saved for label: Fe-Sulphide_Cu
#
#
# [INFO] Starting processing for label: W-Oxide
# [INFO] File size: 35.79 MB
# [INFO] Chunk size: 3.58 MB
# [INFO] Chunk 1: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 2: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 3: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 4: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 5: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 6: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 7: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 8: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 9: Sampled 449 out of 449 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 4041 valid rows.
# [SUMMARY] For label W-Oxide: out of 4041 valid rows, 4041 rows were sampled.
# [INFO] Sampled data saved for label: W-Oxide
#
#
# [INFO] Starting processing for label: Zn-Oxide
# [INFO] File size: 31.90 MB
# [INFO] Chunk size: 3.19 MB
# [INFO] Chunk 1: Sampled 347 out of 347 valid rows.
# [INFO] Chunk 2: Sampled 368 out of 368 valid rows.
# [INFO] Chunk 3: Sampled 394 out of 394 valid rows.
# [INFO] Chunk 4: Sampled 328 out of 328 valid rows.
# [INFO] Chunk 5: Sampled 362 out of 362 valid rows.
# [INFO] Chunk 6: Sampled 382 out of 382 valid rows.
# [INFO] Chunk 7: Sampled 391 out of 391 valid rows.
# [INFO] Chunk 8: Sampled 314 out of 314 valid rows.
# [INFO] Chunk 9: Sampled 400 out of 400 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 3286 valid rows.
# [SUMMARY] For label Zn-Oxide: out of 3286 valid rows, 3286 rows were sampled.
# [INFO] Sampled data saved for label: Zn-Oxide
#
#
# [INFO] Starting processing for label: Fe-sulphide_Pb
# [INFO] File size: 35.74 MB
# [INFO] Chunk size: 3.57 MB
# [INFO] Chunk 1: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 2: Sampled 444 out of 444 valid rows.
# [INFO] Chunk 3: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 4: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 5: Sampled 445 out of 445 valid rows.
# [INFO] Chunk 6: Sampled 449 out of 449 valid rows.
# [INFO] Chunk 7: Sampled 400 out of 400 valid rows.
# [INFO] Chunk 8: Sampled 450 out of 450 valid rows.
# [INFO] Chunk 9: Sampled 449 out of 449 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 3984 valid rows.
# [SUMMARY] For label Fe-sulphide_Pb: out of 3984 valid rows, 3984 rows were sampled.
# [INFO] Sampled data saved for label: Fe-sulphide_Pb
#
#
# [INFO] Starting processing for label: Celestine
# [INFO] File size: 17.94 MB
# [INFO] Chunk size: 1.79 MB
# [INFO] Chunk 1: Sampled 226 out of 226 valid rows.
# [INFO] Chunk 2: Sampled 225 out of 225 valid rows.
# [INFO] Chunk 3: Sampled 226 out of 226 valid rows.
# [INFO] Chunk 4: Sampled 191 out of 191 valid rows.
# [INFO] Chunk 5: Sampled 226 out of 226 valid rows.
# [INFO] Chunk 6: Sampled 226 out of 226 valid rows.
# [INFO] Chunk 7: Sampled 216 out of 216 valid rows.
# [INFO] Chunk 8: Sampled 226 out of 226 valid rows.
# [INFO] Chunk 9: Sampled 226 out of 226 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 1988 valid rows.
# [SUMMARY] For label Celestine: out of 1988 valid rows, 1988 rows were sampled.
# [INFO] Sampled data saved for label: Celestine
#
#
# [INFO] Starting processing for label: Mn-Oxide
# [INFO] File size: 22.05 MB
# [INFO] Chunk size: 2.21 MB
# [INFO] Chunk 1: Sampled 269 out of 269 valid rows.
# [INFO] Chunk 2: Sampled 277 out of 277 valid rows.
# [INFO] Chunk 3: Sampled 264 out of 264 valid rows.
# [INFO] Chunk 4: Sampled 277 out of 277 valid rows.
# [INFO] Chunk 5: Sampled 248 out of 248 valid rows.
# [INFO] Chunk 6: Sampled 275 out of 275 valid rows.
# [INFO] Chunk 7: Sampled 277 out of 277 valid rows.
# [INFO] Chunk 8: Sampled 253 out of 253 valid rows.
# [INFO] Chunk 9: Sampled 275 out of 275 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 2415 valid rows.
# [SUMMARY] For label Mn-Oxide: out of 2415 valid rows, 2415 rows were sampled.
# [INFO] Sampled data saved for label: Mn-Oxide
#
#
# [INFO] Starting processing for label: Columbite_Mn
# [INFO] File size: 27.35 MB
# [INFO] Chunk size: 2.74 MB
# [INFO] Chunk 1: Sampled 306 out of 306 valid rows.
# [INFO] Chunk 2: Sampled 337 out of 337 valid rows.
# [INFO] Chunk 3: Sampled 342 out of 342 valid rows.
# [INFO] Chunk 4: Sampled 313 out of 313 valid rows.
# [INFO] Chunk 5: Sampled 299 out of 299 valid rows.
# [INFO] Chunk 6: Sampled 329 out of 329 valid rows.
# [INFO] Chunk 7: Sampled 318 out of 318 valid rows.
# [INFO] Chunk 8: Sampled 341 out of 341 valid rows.
# [INFO] Chunk 9: Sampled 336 out of 336 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 2921 valid rows.
# [SUMMARY] For label Columbite_Mn: out of 2921 valid rows, 2921 rows were sampled.
# [INFO] Sampled data saved for label: Columbite_Mn
#
#
# [INFO] Starting processing for label: Cu-Oxide
# [INFO] File size: 26.98 MB
# [INFO] Chunk size: 2.70 MB
# [INFO] Chunk 1: Sampled 317 out of 317 valid rows.
# [INFO] Chunk 2: Sampled 340 out of 340 valid rows.
# [INFO] Chunk 3: Sampled 339 out of 339 valid rows.
# [INFO] Chunk 4: Sampled 338 out of 338 valid rows.
# [INFO] Chunk 5: Sampled 340 out of 340 valid rows.
# [INFO] Chunk 6: Sampled 340 out of 340 valid rows.
# [INFO] Chunk 7: Sampled 311 out of 311 valid rows.
# [INFO] Chunk 8: Sampled 340 out of 340 valid rows.
# [INFO] Chunk 9: Sampled 340 out of 340 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 3005 valid rows.
# [SUMMARY] For label Cu-Oxide: out of 3005 valid rows, 3005 rows were sampled.
# [INFO] Sampled data saved for label: Cu-Oxide
#
#
# [INFO] Starting processing for label: Nb-bearing phase
# [INFO] File size: 14.47 MB
# [INFO] Chunk size: 1.45 MB
# [INFO] Chunk 1: Sampled 142 out of 142 valid rows.
# [INFO] Chunk 2: Sampled 182 out of 182 valid rows.
# [INFO] Chunk 3: Sampled 178 out of 178 valid rows.
# [INFO] Chunk 4: Sampled 175 out of 175 valid rows.
# [INFO] Chunk 5: Sampled 157 out of 157 valid rows.
# [INFO] Chunk 6: Sampled 174 out of 174 valid rows.
# [INFO] Chunk 7: Sampled 129 out of 129 valid rows.
# [INFO] Chunk 8: Sampled 181 out of 181 valid rows.
# [INFO] Chunk 9: Sampled 180 out of 180 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 1498 valid rows.
# [SUMMARY] For label Nb-bearing phase: out of 1498 valid rows, 1498 rows were sampled.
# [INFO] Sampled data saved for label: Nb-bearing phase
#
#
# [INFO] Starting processing for label: REE-Silicate
# [INFO] File size: 15.63 MB
# [INFO] Chunk size: 1.56 MB
# [INFO] Chunk 1: Sampled 170 out of 170 valid rows.
# [INFO] Chunk 2: Sampled 132 out of 132 valid rows.
# [INFO] Chunk 3: Sampled 180 out of 180 valid rows.
# [INFO] Chunk 4: Sampled 188 out of 188 valid rows.
# [INFO] Chunk 5: Sampled 196 out of 196 valid rows.
# [INFO] Chunk 6: Sampled 146 out of 146 valid rows.
# [INFO] Chunk 7: Sampled 171 out of 171 valid rows.
# [INFO] Chunk 8: Sampled 82 out of 82 valid rows.
# [INFO] Chunk 9: Sampled 195 out of 195 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 1460 valid rows.
# [SUMMARY] For label REE-Silicate: out of 1460 valid rows, 1460 rows were sampled.
# [INFO] Sampled data saved for label: REE-Silicate
#
#
# [INFO] Starting processing for label: Molybdenite
# [INFO] File size: 16.31 MB
# [INFO] Chunk size: 1.63 MB
# [INFO] Chunk 1: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 2: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 3: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 4: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 5: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 6: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 7: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 8: Sampled 205 out of 205 valid rows.
# [INFO] Chunk 9: Sampled 205 out of 205 valid rows.
# [INFO] File has less than 10,000 valid rows. Saving all 1845 valid rows.
# [SUMMARY] For label Molybdenite: out of 1845 valid rows, 1845 rows were sampled.
# [INFO] Sampled data saved for label: Molybdenite
#
# [DONE] All files processed.

# %%
#Path directory
combined_data_folder = "E:\CP_raw_data"
label_data_folder = "E:\CP_processed_data"

# Create the desired header structure
desired_header = ["x", "y", "yinv"] + [f"CH_{i}" for i in range(1, 4097)] + ["Sum", "Mineral Phase"]

# %%
# Combine samples
for idx in range(1, 79):  # For combined_data_1.csv to combined_data_78.csv
    combined_data_path = os.path.join(combined_data_folder, f"combined_data_{idx}.csv")

    with open(combined_data_path, 'r') as infile:
        reader = csv.reader(infile)
        header = next(reader)

        # Check if columns are misordered and rearrange them
        if header != desired_header:
            print(f"[INFO] Reordering columns for combined_data_{idx}.csv")
            data = list(reader)
            col_indices = [header.index(col_name) for col_name in desired_header]
            rearranged_data = [[row[i] for i in col_indices] for row in data]
        else:
            rearranged_data = list(reader)
            print(f"[INFO] Columns in combined_data_{idx}.csv are in correct order")

        appended_counts = {}  # To track how many samples were appended for each label

        # Append rows to respective {label}.csv
        for row in rearranged_data:
            label = row[-1]  # Assuming Mineral Phase is the last column
            label_file_path = os.path.join(label_data_folder, f"{label}.csv")
            
            with open(label_file_path, 'a', newline='') as label_file:
                writer = csv.writer(label_file)
                writer.writerow(row)

            # Update counts
            appended_counts[label] = appended_counts.get(label, 0) + 1

        # Report how many samples were appended for each label
        for label, count in appended_counts.items():
            print(f"[INFO] Appended {count} samples from combined_data_{idx}.csv to {label}.csv")

    print(f"[INFO] Finished processing combined_data_{idx}.csv")
    print("-" * 50)

# Display the total sample number in each file
print("\n[SUMMARY]")
for filename in os.listdir(label_data_folder):
    file_path = os.path.join(label_data_folder, filename)
    with open(file_path, 'r') as f:
        total_samples = sum(1 for line in f) - 1  # -1 to exclude the header
        print(f"For {filename}: Total samples = {total_samples}")

print("\n[DONE] All files processed.")
# Out:
# [INFO] Columns in combined_data_1.csv are in correct order
# [INFO] Appended 89 samples from combined_data_1.csv to AlFe-Silicate.csv
# [INFO] Appended 145 samples from combined_data_1.csv to Fe-Silicate.csv
# [INFO] Appended 122 samples from combined_data_1.csv to AlK-Silicate.csv
# [INFO] Appended 108 samples from combined_data_1.csv to Zn-Oxide.csv
# [INFO] Appended 139 samples from combined_data_1.csv to Quartz.csv
# [INFO] Appended 23 samples from combined_data_1.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 132 samples from combined_data_1.csv to Rutile.csv
# [INFO] Appended 62 samples from combined_data_1.csv to Epidote.csv
# [INFO] Appended 66 samples from combined_data_1.csv to Amphibole.csv
# [INFO] Appended 176 samples from combined_data_1.csv to Titanite.csv
# [INFO] Appended 102 samples from combined_data_1.csv to AlMn-Silicate.csv
# [INFO] Appended 97 samples from combined_data_1.csv to Monazite.csv
# [INFO] Appended 51 samples from combined_data_1.csv to Zircon.csv
# [INFO] Appended 5 samples from combined_data_1.csv to REE-Silicate.csv
# [INFO] Appended 35 samples from combined_data_1.csv to Al-Silicate.csv
# [INFO] Appended 13 samples from combined_data_1.csv to AlCa-Silicate.csv
# [INFO] Appended 29 samples from combined_data_1.csv to Al-Oxide.csv
# [INFO] Appended 384 samples from combined_data_1.csv to Leucoxene.csv
# [INFO] Appended 16 samples from combined_data_1.csv to Chromite.csv
# [INFO] Appended 53 samples from combined_data_1.csv to Fe-Sulphide.csv
# [INFO] Appended 108 samples from combined_data_1.csv to Apatite.csv
# [INFO] Appended 2 samples from combined_data_1.csv to Mn-Oxide.csv
# [INFO] Appended 6 samples from combined_data_1.csv to Nb-bearing phase.csv
# [INFO] Appended 25 samples from combined_data_1.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 44 samples from combined_data_1.csv to Cu-Oxide.csv
# [INFO] Appended 1 samples from combined_data_1.csv to Fe-Sulphide_Cu.csv
# [INFO] Finished processing combined_data_1.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_2.csv are in correct order
# [INFO] Appended 28 samples from combined_data_2.csv to Epidote.csv
# [INFO] Appended 25 samples from combined_data_2.csv to Amphibole.csv
# [INFO] Appended 25 samples from combined_data_2.csv to AlFe-Silicate.csv
# [INFO] Appended 34 samples from combined_data_2.csv to Fe-Silicate.csv
# [INFO] Appended 56 samples from combined_data_2.csv to Rutile.csv
# [INFO] Appended 72 samples from combined_data_2.csv to Quartz.csv
# [INFO] Appended 40 samples from combined_data_2.csv to Cassiterite.csv
# [INFO] Appended 38 samples from combined_data_2.csv to Barite.csv
# [INFO] Appended 107 samples from combined_data_2.csv to AlCa-Silicate.csv
# [INFO] Appended 7 samples from combined_data_2.csv to Apatite.csv
# [INFO] Appended 140 samples from combined_data_2.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 103 samples from combined_data_2.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 74 samples from combined_data_2.csv to Cu-Oxide.csv
# [INFO] Appended 144 samples from combined_data_2.csv to Chromite.csv
# [INFO] Appended 38 samples from combined_data_2.csv to Zircon.csv
# [INFO] Appended 33 samples from combined_data_2.csv to AlK-Silicate.csv
# [INFO] Appended 48 samples from combined_data_2.csv to Al-Silicate.csv
# [INFO] Appended 171 samples from combined_data_2.csv to Carbonate.csv
# [INFO] Appended 31 samples from combined_data_2.csv to Al-Oxide.csv
# [INFO] Appended 26 samples from combined_data_2.csv to Zn-Oxide.csv
# [INFO] Appended 55 samples from combined_data_2.csv to Celestine.csv
# [INFO] Appended 83 samples from combined_data_2.csv to Columbite_Mn.csv
# [INFO] Appended 66 samples from combined_data_2.csv to Monazite.csv
# [INFO] Appended 15 samples from combined_data_2.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 19 samples from combined_data_2.csv to AlMn-Silicate.csv
# [INFO] Appended 21 samples from combined_data_2.csv to Mn-Oxide.csv
# [INFO] Appended 71 samples from combined_data_2.csv to Molybdenite.csv
# [INFO] Appended 20 samples from combined_data_2.csv to Leucoxene.csv
# [INFO] Appended 76 samples from combined_data_2.csv to Fe-Sulphide.csv
# [INFO] Appended 139 samples from combined_data_2.csv to W-Oxide.csv
# [INFO] Appended 48 samples from combined_data_2.csv to Titanite.csv
# [INFO] Appended 21 samples from combined_data_2.csv to Nb-bearing phase.csv
# [INFO] Appended 112 samples from combined_data_2.csv to Xenotime.csv
# [INFO] Appended 23 samples from combined_data_2.csv to Thorite.csv
# [INFO] Appended 3 samples from combined_data_2.csv to REE-Silicate.csv
# [INFO] Finished processing combined_data_2.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_3.csv are in correct order
# [INFO] Appended 16 samples from combined_data_3.csv to Epidote.csv
# [INFO] Appended 27 samples from combined_data_3.csv to Amphibole.csv
# [INFO] Appended 28 samples from combined_data_3.csv to AlFe-Silicate.csv
# [INFO] Appended 46 samples from combined_data_3.csv to Fe-Silicate.csv
# [INFO] Appended 10 samples from combined_data_3.csv to Titanite.csv
# [INFO] Appended 85 samples from combined_data_3.csv to Rutile.csv
# [INFO] Appended 55 samples from combined_data_3.csv to Zircon.csv
# [INFO] Appended 35 samples from combined_data_3.csv to AlK-Silicate.csv
# [INFO] Appended 17 samples from combined_data_3.csv to Leucoxene.csv
# [INFO] Appended 28 samples from combined_data_3.csv to Fe-Sulphide.csv
# [INFO] Appended 46 samples from combined_data_3.csv to AlMn-Silicate.csv
# [INFO] Appended 53 samples from combined_data_3.csv to Quartz.csv
# [INFO] Appended 104 samples from combined_data_3.csv to Barite.csv
# [INFO] Appended 230 samples from combined_data_3.csv to Al-Silicate.csv
# [INFO] Appended 82 samples from combined_data_3.csv to Apatite.csv
# [INFO] Appended 57 samples from combined_data_3.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 107 samples from combined_data_3.csv to Al-Oxide.csv
# [INFO] Appended 89 samples from combined_data_3.csv to Monazite.csv
# [INFO] Appended 34 samples from combined_data_3.csv to Zn-Oxide.csv
# [INFO] Appended 126 samples from combined_data_3.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 113 samples from combined_data_3.csv to Cu-Oxide.csv
# [INFO] Appended 38 samples from combined_data_3.csv to Cassiterite.csv
# [INFO] Appended 53 samples from combined_data_3.csv to AlCa-Silicate.csv
# [INFO] Appended 106 samples from combined_data_3.csv to Chromite.csv
# [INFO] Appended 166 samples from combined_data_3.csv to Carbonate.csv
# [INFO] Appended 132 samples from combined_data_3.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 58 samples from combined_data_3.csv to Celestine.csv
# [INFO] Appended 40 samples from combined_data_3.csv to Columbite_Mn.csv
# [INFO] Appended 1 samples from combined_data_3.csv to Nb-bearing phase.csv
# [INFO] Appended 2 samples from combined_data_3.csv to Mn-Oxide.csv
# [INFO] Appended 71 samples from combined_data_3.csv to Molybdenite.csv
# [INFO] Finished processing combined_data_3.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_4.csv are in correct order
# [INFO] Appended 30 samples from combined_data_4.csv to Epidote.csv
# [INFO] Appended 33 samples from combined_data_4.csv to Amphibole.csv
# [INFO] Appended 57 samples from combined_data_4.csv to AlFe-Silicate.csv
# [INFO] Appended 99 samples from combined_data_4.csv to Fe-Silicate.csv
# [INFO] Appended 81 samples from combined_data_4.csv to AlMn-Silicate.csv
# [INFO] Appended 237 samples from combined_data_4.csv to Quartz.csv
# [INFO] Appended 36 samples from combined_data_4.csv to Chromite.csv
# [INFO] Appended 49 samples from combined_data_4.csv to Fe-Sulphide.csv
# [INFO] Appended 67 samples from combined_data_4.csv to AlCa-Silicate.csv
# [INFO] Appended 24 samples from combined_data_4.csv to Mn-Oxide.csv
# [INFO] Appended 156 samples from combined_data_4.csv to Rutile.csv
# [INFO] Appended 134 samples from combined_data_4.csv to AlK-Silicate.csv
# [INFO] Appended 148 samples from combined_data_4.csv to W-Oxide.csv
# [INFO] Appended 55 samples from combined_data_4.csv to Titanite.csv
# [INFO] Appended 43 samples from combined_data_4.csv to Leucoxene.csv
# [INFO] Appended 10 samples from combined_data_4.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 51 samples from combined_data_4.csv to Columbite_Mn.csv
# [INFO] Appended 19 samples from combined_data_4.csv to Nb-bearing phase.csv
# [INFO] Appended 250 samples from combined_data_4.csv to Al-Silicate.csv
# [INFO] Appended 103 samples from combined_data_4.csv to Xenotime.csv
# [INFO] Appended 25 samples from combined_data_4.csv to Thorite.csv
# [INFO] Appended 1 samples from combined_data_4.csv to Carbonate.csv
# [INFO] Appended 23 samples from combined_data_4.csv to Zircon.csv
# [INFO] Appended 236 samples from combined_data_4.csv to Monazite.csv
# [INFO] Appended 7 samples from combined_data_4.csv to REE-Silicate.csv
# [INFO] Appended 17 samples from combined_data_4.csv to Barite.csv
# [INFO] Appended 1 samples from combined_data_4.csv to Celestine.csv
# [INFO] Appended 5 samples from combined_data_4.csv to Zn-Oxide.csv
# [INFO] Appended 15 samples from combined_data_4.csv to Al-Oxide.csv
# [INFO] Finished processing combined_data_4.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_5.csv are in correct order
# [INFO] Appended 50 samples from combined_data_5.csv to AlFe-Silicate.csv
# [INFO] Appended 91 samples from combined_data_5.csv to Fe-Silicate.csv
# [INFO] Appended 101 samples from combined_data_5.csv to Rutile.csv
# [INFO] Appended 61 samples from combined_data_5.csv to Barite.csv
# [INFO] Appended 13 samples from combined_data_5.csv to Zircon.csv
# [INFO] Appended 35 samples from combined_data_5.csv to Quartz.csv
# [INFO] Appended 92 samples from combined_data_5.csv to AlK-Silicate.csv
# [INFO] Appended 6 samples from combined_data_5.csv to Leucoxene.csv
# [INFO] Appended 89 samples from combined_data_5.csv to Monazite.csv
# [INFO] Appended 33 samples from combined_data_5.csv to Celestine.csv
# [INFO] Appended 43 samples from combined_data_5.csv to Epidote.csv
# [INFO] Appended 45 samples from combined_data_5.csv to Amphibole.csv
# [INFO] Appended 88 samples from combined_data_5.csv to Titanite.csv
# [INFO] Appended 80 samples from combined_data_5.csv to AlMn-Silicate.csv
# [INFO] Appended 131 samples from combined_data_5.csv to AlCa-Silicate.csv
# [INFO] Appended 212 samples from combined_data_5.csv to Al-Silicate.csv
# [INFO] Appended 12 samples from combined_data_5.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 30 samples from combined_data_5.csv to Apatite.csv
# [INFO] Appended 106 samples from combined_data_5.csv to Chromite.csv
# [INFO] Appended 74 samples from combined_data_5.csv to Al-Oxide.csv
# [INFO] Appended 140 samples from combined_data_5.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 80 samples from combined_data_5.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 57 samples from combined_data_5.csv to Cu-Oxide.csv
# [INFO] Appended 40 samples from combined_data_5.csv to Cassiterite.csv
# [INFO] Appended 193 samples from combined_data_5.csv to Carbonate.csv
# [INFO] Appended 24 samples from combined_data_5.csv to Columbite_Mn.csv
# [INFO] Appended 39 samples from combined_data_5.csv to Zn-Oxide.csv
# [INFO] Appended 7 samples from combined_data_5.csv to Mn-Oxide.csv
# [INFO] Appended 32 samples from combined_data_5.csv to Molybdenite.csv
# [INFO] Appended 1 samples from combined_data_5.csv to Fe-Sulphide.csv
# [INFO] Finished processing combined_data_5.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_6.csv are in correct order
# [INFO] Appended 59 samples from combined_data_6.csv to Epidote.csv
# [INFO] Appended 57 samples from combined_data_6.csv to Amphibole.csv
# [INFO] Appended 142 samples from combined_data_6.csv to Fe-Silicate.csv
# [INFO] Appended 132 samples from combined_data_6.csv to AlMn-Silicate.csv
# [INFO] Appended 189 samples from combined_data_6.csv to Quartz.csv
# [INFO] Appended 62 samples from combined_data_6.csv to Chromite.csv
# [INFO] Appended 37 samples from combined_data_6.csv to Fe-Sulphide.csv
# [INFO] Appended 96 samples from combined_data_6.csv to AlCa-Silicate.csv
# [INFO] Appended 21 samples from combined_data_6.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 11 samples from combined_data_6.csv to Mn-Oxide.csv
# [INFO] Appended 72 samples from combined_data_6.csv to AlFe-Silicate.csv
# [INFO] Appended 207 samples from combined_data_6.csv to Monazite.csv
# [INFO] Appended 64 samples from combined_data_6.csv to W-Oxide.csv
# [INFO] Appended 138 samples from combined_data_6.csv to Rutile.csv
# [INFO] Appended 6 samples from combined_data_6.csv to Carbonate.csv
# [INFO] Appended 17 samples from combined_data_6.csv to Nb-bearing phase.csv
# [INFO] Appended 68 samples from combined_data_6.csv to Xenotime.csv
# [INFO] Appended 61 samples from combined_data_6.csv to Al-Silicate.csv
# [INFO] Appended 46 samples from combined_data_6.csv to Thorite.csv
# [INFO] Appended 19 samples from combined_data_6.csv to Columbite_Mn.csv
# [INFO] Appended 153 samples from combined_data_6.csv to Zircon.csv
# [INFO] Appended 145 samples from combined_data_6.csv to Titanite.csv
# [INFO] Appended 38 samples from combined_data_6.csv to REE-Silicate.csv
# [INFO] Appended 62 samples from combined_data_6.csv to Leucoxene.csv
# [INFO] Appended 86 samples from combined_data_6.csv to AlK-Silicate.csv
# [INFO] Appended 5 samples from combined_data_6.csv to Barite.csv
# [INFO] Appended 3 samples from combined_data_6.csv to Al-Oxide.csv
# [INFO] Appended 10 samples from combined_data_6.csv to Celestine.csv
# [INFO] Appended 7 samples from combined_data_6.csv to Apatite.csv
# [INFO] Finished processing combined_data_6.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_7.csv are in correct order
# [INFO] Appended 68 samples from combined_data_7.csv to Epidote.csv
# [INFO] Appended 72 samples from combined_data_7.csv to Amphibole.csv
# [INFO] Appended 98 samples from combined_data_7.csv to AlFe-Silicate.csv
# [INFO] Appended 170 samples from combined_data_7.csv to Fe-Silicate.csv
# [INFO] Appended 200 samples from combined_data_7.csv to Titanite.csv
# [INFO] Appended 180 samples from combined_data_7.csv to AlMn-Silicate.csv
# [INFO] Appended 189 samples from combined_data_7.csv to AlK-Silicate.csv
# [INFO] Appended 69 samples from combined_data_7.csv to Al-Silicate.csv
# [INFO] Appended 51 samples from combined_data_7.csv to AlCa-Silicate.csv
# [INFO] Appended 196 samples from combined_data_7.csv to Monazite.csv
# [INFO] Appended 268 samples from combined_data_7.csv to Quartz.csv
# [INFO] Appended 152 samples from combined_data_7.csv to Zircon.csv
# [INFO] Appended 12 samples from combined_data_7.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 103 samples from combined_data_7.csv to Rutile.csv
# [INFO] Appended 25 samples from combined_data_7.csv to Xenotime.csv
# [INFO] Appended 55 samples from combined_data_7.csv to Leucoxene.csv
# [INFO] Appended 12 samples from combined_data_7.csv to Thorite.csv
# [INFO] Appended 11 samples from combined_data_7.csv to REE-Silicate.csv
# [INFO] Appended 14 samples from combined_data_7.csv to Chromite.csv
# [INFO] Appended 2 samples from combined_data_7.csv to Al-Oxide.csv
# [INFO] Appended 5 samples from combined_data_7.csv to Zn-Oxide.csv
# [INFO] Appended 46 samples from combined_data_7.csv to Mn-Oxide.csv
# [INFO] Appended 5 samples from combined_data_7.csv to Cassiterite.csv
# [INFO] Appended 2 samples from combined_data_7.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 4 samples from combined_data_7.csv to Apatite.csv
# [INFO] Finished processing combined_data_7.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_8.csv are in correct order
# [INFO] Appended 105 samples from combined_data_8.csv to Epidote.csv
# [INFO] Appended 114 samples from combined_data_8.csv to Amphibole.csv
# [INFO] Appended 121 samples from combined_data_8.csv to AlFe-Silicate.csv
# [INFO] Appended 209 samples from combined_data_8.csv to Fe-Silicate.csv
# [INFO] Appended 296 samples from combined_data_8.csv to Titanite.csv
# [INFO] Appended 95 samples from combined_data_8.csv to Quartz.csv
# [INFO] Appended 106 samples from combined_data_8.csv to Zircon.csv
# [INFO] Appended 1 samples from combined_data_8.csv to Xenotime.csv
# [INFO] Appended 134 samples from combined_data_8.csv to AlK-Silicate.csv
# [INFO] Appended 131 samples from combined_data_8.csv to Monazite.csv
# [INFO] Appended 59 samples from combined_data_8.csv to AlCa-Silicate.csv
# [INFO] Appended 92 samples from combined_data_8.csv to Rutile.csv
# [INFO] Appended 19 samples from combined_data_8.csv to REE-Silicate.csv
# [INFO] Appended 51 samples from combined_data_8.csv to Leucoxene.csv
# [INFO] Appended 208 samples from combined_data_8.csv to AlMn-Silicate.csv
# [INFO] Appended 27 samples from combined_data_8.csv to Fe-Sulphide.csv
# [INFO] Appended 13 samples from combined_data_8.csv to Apatite.csv
# [INFO] Appended 20 samples from combined_data_8.csv to Mn-Oxide.csv
# [INFO] Appended 32 samples from combined_data_8.csv to Chromite.csv
# [INFO] Appended 57 samples from combined_data_8.csv to Al-Silicate.csv
# [INFO] Appended 83 samples from combined_data_8.csv to Barite.csv
# [INFO] Appended 3 samples from combined_data_8.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 2 samples from combined_data_8.csv to Al-Oxide.csv
# [INFO] Appended 7 samples from combined_data_8.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 6 samples from combined_data_8.csv to Nb-bearing phase.csv
# [INFO] Appended 10 samples from combined_data_8.csv to Celestine.csv
# [INFO] Finished processing combined_data_8.csv
# --------------------------------------------------
# [INFO] Reordering columns for combined_data_9.csv
# [INFO] Appended 52 samples from combined_data_9.csv to Epidote.csv
# [INFO] Appended 53 samples from combined_data_9.csv to Amphibole.csv
# [INFO] Appended 71 samples from combined_data_9.csv to AlFe-Silicate.csv
# [INFO] Appended 123 samples from combined_data_9.csv to Fe-Silicate.csv
# [INFO] Appended 138 samples from combined_data_9.csv to Titanite.csv
# [INFO] Appended 73 samples from combined_data_9.csv to AlMn-Silicate.csv
# [INFO] Appended 493 samples from combined_data_9.csv to Leucoxene.csv
# [INFO] Appended 89 samples from combined_data_9.csv to Quartz.csv
# [INFO] Appended 23 samples from combined_data_9.csv to AlCa-Silicate.csv
# [INFO] Appended 26 samples from combined_data_9.csv to Thorite.csv
# [INFO] Appended 180 samples from combined_data_9.csv to Monazite.csv
# [INFO] Appended 113 samples from combined_data_9.csv to AlK-Silicate.csv
# [INFO] Appended 7 samples from combined_data_9.csv to Xenotime.csv
# [INFO] Appended 184 samples from combined_data_9.csv to Rutile.csv
# [INFO] Appended 2 samples from combined_data_9.csv to Nb-bearing phase.csv
# [INFO] Appended 15 samples from combined_data_9.csv to REE-Silicate.csv
# [INFO] Appended 142 samples from combined_data_9.csv to Al-Silicate.csv
# [INFO] Appended 25 samples from combined_data_9.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 107 samples from combined_data_9.csv to Zircon.csv
# [INFO] Appended 4 samples from combined_data_9.csv to Zn-Oxide.csv
# [INFO] Appended 25 samples from combined_data_9.csv to Barite.csv
# [INFO] Appended 3 samples from combined_data_9.csv to Apatite.csv
# [INFO] Appended 10 samples from combined_data_9.csv to Al-Oxide.csv
# [INFO] Appended 10 samples from combined_data_9.csv to Celestine.csv
# [INFO] Appended 42 samples from combined_data_9.csv to Columbite_Mn.csv
# [INFO] Finished processing combined_data_9.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_10.csv are in correct order
# [INFO] Appended 22 samples from combined_data_10.csv to AlFe-Silicate.csv
# [INFO] Appended 42 samples from combined_data_10.csv to Fe-Silicate.csv
# [INFO] Appended 91 samples from combined_data_10.csv to Rutile.csv
# [INFO] Appended 88 samples from combined_data_10.csv to Zircon.csv
# [INFO] Appended 127 samples from combined_data_10.csv to Al-Silicate.csv
# [INFO] Appended 44 samples from combined_data_10.csv to Leucoxene.csv
# [INFO] Appended 54 samples from combined_data_10.csv to Barite.csv
# [INFO] Appended 64 samples from combined_data_10.csv to Monazite.csv
# [INFO] Appended 30 samples from combined_data_10.csv to AlK-Silicate.csv
# [INFO] Appended 1 samples from combined_data_10.csv to Xenotime.csv
# [INFO] Appended 3 samples from combined_data_10.csv to REE-Silicate.csv
# [INFO] Appended 14 samples from combined_data_10.csv to Epidote.csv
# [INFO] Appended 14 samples from combined_data_10.csv to Amphibole.csv
# [INFO] Appended 26 samples from combined_data_10.csv to AlMn-Silicate.csv
# [INFO] Appended 53 samples from combined_data_10.csv to Quartz.csv
# [INFO] Appended 86 samples from combined_data_10.csv to Apatite.csv
# [INFO] Appended 26 samples from combined_data_10.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 54 samples from combined_data_10.csv to Al-Oxide.csv
# [INFO] Appended 133 samples from combined_data_10.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 110 samples from combined_data_10.csv to Cu-Oxide.csv
# [INFO] Appended 109 samples from combined_data_10.csv to AlCa-Silicate.csv
# [INFO] Appended 144 samples from combined_data_10.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 38 samples from combined_data_10.csv to Cassiterite.csv
# [INFO] Appended 127 samples from combined_data_10.csv to Chromite.csv
# [INFO] Appended 169 samples from combined_data_10.csv to Carbonate.csv
# [INFO] Appended 27 samples from combined_data_10.csv to Zn-Oxide.csv
# [INFO] Appended 59 samples from combined_data_10.csv to Celestine.csv
# [INFO] Appended 44 samples from combined_data_10.csv to Columbite_Mn.csv
# [INFO] Appended 59 samples from combined_data_10.csv to Fe-Sulphide.csv
# [INFO] Appended 19 samples from combined_data_10.csv to Mn-Oxide.csv
# [INFO] Appended 71 samples from combined_data_10.csv to Molybdenite.csv
# [INFO] Appended 72 samples from combined_data_10.csv to W-Oxide.csv
# [INFO] Appended 6 samples from combined_data_10.csv to Titanite.csv
# [INFO] Appended 19 samples from combined_data_10.csv to Nb-bearing phase.csv
# [INFO] Finished processing combined_data_10.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_11.csv are in correct order
# [INFO] Appended 18 samples from combined_data_11.csv to Epidote.csv
# [INFO] Appended 79 samples from combined_data_11.csv to AlFe-Silicate.csv
# [INFO] Appended 125 samples from combined_data_11.csv to Fe-Silicate.csv
# [INFO] Appended 26 samples from combined_data_11.csv to Titanite.csv
# [INFO] Appended 187 samples from combined_data_11.csv to Rutile.csv
# [INFO] Appended 90 samples from combined_data_11.csv to Quartz.csv
# [INFO] Appended 105 samples from combined_data_11.csv to Al-Silicate.csv
# [INFO] Appended 18 samples from combined_data_11.csv to Chromite.csv
# [INFO] Appended 1 samples from combined_data_11.csv to Fe-Sulphide.csv
# [INFO] Appended 129 samples from combined_data_11.csv to Xenotime.csv
# [INFO] Appended 38 samples from combined_data_11.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 75 samples from combined_data_11.csv to W-Oxide.csv
# [INFO] Appended 76 samples from combined_data_11.csv to Columbite_Mn.csv
# [INFO] Appended 25 samples from combined_data_11.csv to Nb-bearing phase.csv
# [INFO] Appended 19 samples from combined_data_11.csv to Thorite.csv
# [INFO] Appended 37 samples from combined_data_11.csv to Amphibole.csv
# [INFO] Appended 132 samples from combined_data_11.csv to Zircon.csv
# [INFO] Appended 4 samples from combined_data_11.csv to AlCa-Silicate.csv
# [INFO] Appended 229 samples from combined_data_11.csv to AlK-Silicate.csv
# [INFO] Appended 211 samples from combined_data_11.csv to Leucoxene.csv
# [INFO] Appended 14 samples from combined_data_11.csv to Al-Oxide.csv
# [INFO] Appended 61 samples from combined_data_11.csv to Zn-Oxide.csv
# [INFO] Appended 60 samples from combined_data_11.csv to AlMn-Silicate.csv
# [INFO] Appended 159 samples from combined_data_11.csv to Monazite.csv
# [INFO] Appended 16 samples from combined_data_11.csv to Mn-Oxide.csv
# [INFO] Appended 78 samples from combined_data_11.csv to Barite.csv
# [INFO] Appended 8 samples from combined_data_11.csv to REE-Silicate.csv
# [INFO] Appended 5 samples from combined_data_11.csv to Carbonate.csv
# [INFO] Appended 4 samples from combined_data_11.csv to Celestine.csv
# [INFO] Finished processing combined_data_11.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_12.csv are in correct order
# [INFO] Appended 70 samples from combined_data_12.csv to AlFe-Silicate.csv
# [INFO] Appended 133 samples from combined_data_12.csv to Fe-Silicate.csv
# [INFO] Appended 206 samples from combined_data_12.csv to Rutile.csv
# [INFO] Appended 96 samples from combined_data_12.csv to Zircon.csv
# [INFO] Appended 24 samples from combined_data_12.csv to Monazite.csv
# [INFO] Appended 72 samples from combined_data_12.csv to Quartz.csv
# [INFO] Appended 193 samples from combined_data_12.csv to Barite.csv
# [INFO] Appended 108 samples from combined_data_12.csv to Leucoxene.csv
# [INFO] Appended 62 samples from combined_data_12.csv to Amphibole.csv
# [INFO] Appended 49 samples from combined_data_12.csv to AlK-Silicate.csv
# [INFO] Appended 108 samples from combined_data_12.csv to Al-Silicate.csv
# [INFO] Appended 52 samples from combined_data_12.csv to Al-Oxide.csv
# [INFO] Appended 33 samples from combined_data_12.csv to Nb-bearing phase.csv
# [INFO] Appended 120 samples from combined_data_12.csv to AlMn-Silicate.csv
# [INFO] Appended 1 samples from combined_data_12.csv to Fe-Sulphide.csv
# [INFO] Appended 6 samples from combined_data_12.csv to Xenotime.csv
# [INFO] Appended 129 samples from combined_data_12.csv to Titanite.csv
# [INFO] Appended 12 samples from combined_data_12.csv to Carbonate.csv
# [INFO] Appended 164 samples from combined_data_12.csv to Mn-Oxide.csv
# [INFO] Appended 10 samples from combined_data_12.csv to Columbite_Mn.csv
# [INFO] Appended 62 samples from combined_data_12.csv to Epidote.csv
# [INFO] Appended 21 samples from combined_data_12.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 9 samples from combined_data_12.csv to Zn-Oxide.csv
# [INFO] Appended 39 samples from combined_data_12.csv to AlCa-Silicate.csv
# [INFO] Appended 223 samples from combined_data_12.csv to Chromite.csv
# [INFO] Finished processing combined_data_12.csv
# --------------------------------------------------
# [INFO] Reordering columns for combined_data_13.csv
# [INFO] Appended 110 samples from combined_data_13.csv to Epidote.csv
# [INFO] Appended 114 samples from combined_data_13.csv to Amphibole.csv
# [INFO] Appended 131 samples from combined_data_13.csv to AlFe-Silicate.csv
# [INFO] Appended 231 samples from combined_data_13.csv to Fe-Silicate.csv
# [INFO] Appended 245 samples from combined_data_13.csv to Titanite.csv
# [INFO] Appended 136 samples from combined_data_13.csv to AlCa-Silicate.csv
# [INFO] Appended 108 samples from combined_data_13.csv to Rutile.csv
# [INFO] Appended 109 samples from combined_data_13.csv to AlK-Silicate.csv
# [INFO] Appended 39 samples from combined_data_13.csv to Apatite.csv
# [INFO] Appended 1 samples from combined_data_13.csv to Nb-bearing phase.csv
# [INFO] Appended 291 samples from combined_data_13.csv to Quartz.csv
# [INFO] Appended 50 samples from combined_data_13.csv to Leucoxene.csv
# [INFO] Appended 15 samples from combined_data_13.csv to Al-Silicate.csv
# [INFO] Appended 153 samples from combined_data_13.csv to Monazite.csv
# [INFO] Appended 33 samples from combined_data_13.csv to Barite.csv
# [INFO] Appended 163 samples from combined_data_13.csv to AlMn-Silicate.csv
# [INFO] Appended 12 samples from combined_data_13.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 3 samples from combined_data_13.csv to Zn-Oxide.csv
# [INFO] Appended 19 samples from combined_data_13.csv to Zircon.csv
# [INFO] Appended 7 samples from combined_data_13.csv to REE-Silicate.csv
# [INFO] Appended 24 samples from combined_data_13.csv to Chromite.csv
# [INFO] Appended 1 samples from combined_data_13.csv to Fe-Sulphide.csv
# [INFO] Appended 3 samples from combined_data_13.csv to Carbonate.csv
# [INFO] Appended 3 samples from combined_data_13.csv to Al-Oxide.csv
# [INFO] Appended 8 samples from combined_data_13.csv to W-Oxide.csv
# [INFO] Appended 8 samples from combined_data_13.csv to Xenotime.csv
# [INFO] Finished processing combined_data_13.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_14.csv are in correct order
# [INFO] Appended 58 samples from combined_data_14.csv to Epidote.csv
# [INFO] Appended 80 samples from combined_data_14.csv to Amphibole.csv
# [INFO] Appended 112 samples from combined_data_14.csv to AlFe-Silicate.csv
# [INFO] Appended 183 samples from combined_data_14.csv to Fe-Silicate.csv
# [INFO] Appended 151 samples from combined_data_14.csv to Titanite.csv
# [INFO] Appended 85 samples from combined_data_14.csv to AlK-Silicate.csv
# [INFO] Appended 149 samples from combined_data_14.csv to AlMn-Silicate.csv
# [INFO] Appended 45 samples from combined_data_14.csv to Quartz.csv
# [INFO] Appended 187 samples from combined_data_14.csv to Leucoxene.csv
# [INFO] Appended 178 samples from combined_data_14.csv to Rutile.csv
# [INFO] Appended 161 samples from combined_data_14.csv to Zircon.csv
# [INFO] Appended 21 samples from combined_data_14.csv to Apatite.csv
# [INFO] Appended 4 samples from combined_data_14.csv to Mn-Oxide.csv
# [INFO] Appended 78 samples from combined_data_14.csv to Monazite.csv
# [INFO] Appended 260 samples from combined_data_14.csv to Al-Silicate.csv
# [INFO] Appended 38 samples from combined_data_14.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 60 samples from combined_data_14.csv to Zn-Oxide.csv
# [INFO] Appended 28 samples from combined_data_14.csv to Barite.csv
# [INFO] Appended 15 samples from combined_data_14.csv to Al-Oxide.csv
# [INFO] Appended 25 samples from combined_data_14.csv to AlCa-Silicate.csv
# [INFO] Appended 36 samples from combined_data_14.csv to Xenotime.csv
# [INFO] Appended 4 samples from combined_data_14.csv to REE-Silicate.csv
# [INFO] Appended 21 samples from combined_data_14.csv to Chromite.csv
# [INFO] Appended 22 samples from combined_data_14.csv to Columbite_Mn.csv
# [INFO] Appended 8 samples from combined_data_14.csv to Nb-bearing phase.csv
# [INFO] Finished processing combined_data_14.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_15.csv are in correct order
# [INFO] Appended 55 samples from combined_data_15.csv to Epidote.csv
# [INFO] Appended 67 samples from combined_data_15.csv to Amphibole.csv
# [INFO] Appended 100 samples from combined_data_15.csv to AlFe-Silicate.csv
# [INFO] Appended 139 samples from combined_data_15.csv to Titanite.csv
# [INFO] Appended 196 samples from combined_data_15.csv to Rutile.csv
# [INFO] Appended 49 samples from combined_data_15.csv to Zircon.csv
# [INFO] Appended 70 samples from combined_data_15.csv to Leucoxene.csv
# [INFO] Appended 186 samples from combined_data_15.csv to Fe-Silicate.csv
# [INFO] Appended 65 samples from combined_data_15.csv to AlK-Silicate.csv
# [INFO] Appended 117 samples from combined_data_15.csv to Monazite.csv
# [INFO] Appended 119 samples from combined_data_15.csv to Quartz.csv
# [INFO] Appended 251 samples from combined_data_15.csv to Barite.csv
# [INFO] Appended 73 samples from combined_data_15.csv to AlMn-Silicate.csv
# [INFO] Appended 78 samples from combined_data_15.csv to AlCa-Silicate.csv
# [INFO] Appended 13 samples from combined_data_15.csv to Apatite.csv
# [INFO] Appended 39 samples from combined_data_15.csv to Chromite.csv
# [INFO] Appended 9 samples from combined_data_15.csv to Mn-Oxide.csv
# [INFO] Appended 56 samples from combined_data_15.csv to Al-Silicate.csv
# [INFO] Appended 1 samples from combined_data_15.csv to REE-Silicate.csv
# [INFO] Appended 15 samples from combined_data_15.csv to Fe-Sulphide.csv
# [INFO] Appended 112 samples from combined_data_15.csv to Carbonate.csv
# [INFO] Appended 9 samples from combined_data_15.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 18 samples from combined_data_15.csv to Al-Oxide.csv
# [INFO] Appended 3 samples from combined_data_15.csv to Zn-Oxide.csv
# [INFO] Appended 38 samples from combined_data_15.csv to Cassiterite.csv
# [INFO] Appended 129 samples from combined_data_15.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 31 samples from combined_data_15.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 36 samples from combined_data_15.csv to Cu-Oxide.csv
# [INFO] Appended 32 samples from combined_data_15.csv to Celestine.csv
# [INFO] Appended 21 samples from combined_data_15.csv to Columbite_Mn.csv
# [INFO] Finished processing combined_data_15.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_16.csv are in correct order
# [INFO] Appended 45 samples from combined_data_16.csv to Epidote.csv
# [INFO] Appended 50 samples from combined_data_16.csv to Amphibole.csv
# [INFO] Appended 59 samples from combined_data_16.csv to AlFe-Silicate.csv
# [INFO] Appended 99 samples from combined_data_16.csv to Fe-Silicate.csv
# [INFO] Appended 127 samples from combined_data_16.csv to Rutile.csv
# [INFO] Appended 138 samples from combined_data_16.csv to Monazite.csv
# [INFO] Appended 216 samples from combined_data_16.csv to AlK-Silicate.csv
# [INFO] Appended 17 samples from combined_data_16.csv to Barite.csv
# [INFO] Appended 104 samples from combined_data_16.csv to Chromite.csv
# [INFO] Appended 89 samples from combined_data_16.csv to Carbonate.csv
# [INFO] Appended 30 samples from combined_data_16.csv to Al-Oxide.csv
# [INFO] Appended 14 samples from combined_data_16.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 44 samples from combined_data_16.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 2 samples from combined_data_16.csv to Celestine.csv
# [INFO] Appended 72 samples from combined_data_16.csv to Titanite.csv
# [INFO] Appended 20 samples from combined_data_16.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 46 samples from combined_data_16.csv to Zn-Oxide.csv
# [INFO] Appended 45 samples from combined_data_16.csv to AlMn-Silicate.csv
# [INFO] Appended 63 samples from combined_data_16.csv to Fe-Sulphide.csv
# [INFO] Appended 53 samples from combined_data_16.csv to AlCa-Silicate.csv
# [INFO] Appended 25 samples from combined_data_16.csv to Mn-Oxide.csv
# [INFO] Appended 92 samples from combined_data_16.csv to Al-Silicate.csv
# [INFO] Appended 149 samples from combined_data_16.csv to Quartz.csv
# [INFO] Appended 17 samples from combined_data_16.csv to Cu-Oxide.csv
# [INFO] Appended 34 samples from combined_data_16.csv to Molybdenite.csv
# [INFO] Appended 63 samples from combined_data_16.csv to W-Oxide.csv
# [INFO] Appended 21 samples from combined_data_16.csv to Nb-bearing phase.csv
# [INFO] Appended 45 samples from combined_data_16.csv to Xenotime.csv
# [INFO] Appended 41 samples from combined_data_16.csv to Thorite.csv
# [INFO] Appended 21 samples from combined_data_16.csv to Columbite_Mn.csv
# [INFO] Appended 108 samples from combined_data_16.csv to Zircon.csv
# [INFO] Appended 61 samples from combined_data_16.csv to Leucoxene.csv
# [INFO] Appended 1 samples from combined_data_16.csv to REE-Silicate.csv
# [INFO] Appended 3 samples from combined_data_16.csv to Apatite.csv
# [INFO] Finished processing combined_data_16.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_17.csv are in correct order
# [INFO] Appended 61 samples from combined_data_17.csv to AlFe-Silicate.csv
# [INFO] Appended 101 samples from combined_data_17.csv to Fe-Silicate.csv
# [INFO] Appended 119 samples from combined_data_17.csv to Rutile.csv
# [INFO] Appended 205 samples from combined_data_17.csv to Zircon.csv
# [INFO] Appended 224 samples from combined_data_17.csv to Monazite.csv
# [INFO] Appended 117 samples from combined_data_17.csv to AlK-Silicate.csv
# [INFO] Appended 121 samples from combined_data_17.csv to Barite.csv
# [INFO] Appended 495 samples from combined_data_17.csv to Al-Silicate.csv
# [INFO] Appended 53 samples from combined_data_17.csv to Leucoxene.csv
# [INFO] Appended 64 samples from combined_data_17.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 36 samples from combined_data_17.csv to Zn-Oxide.csv
# [INFO] Appended 9 samples from combined_data_17.csv to Celestine.csv
# [INFO] Appended 114 samples from combined_data_17.csv to Quartz.csv
# [INFO] Appended 21 samples from combined_data_17.csv to Al-Oxide.csv
# [INFO] Appended 10 samples from combined_data_17.csv to Nb-bearing phase.csv
# [INFO] Appended 36 samples from combined_data_17.csv to Amphibole.csv
# [INFO] Appended 34 samples from combined_data_17.csv to Epidote.csv
# [INFO] Appended 1 samples from combined_data_17.csv to Fe-Sulphide.csv
# [INFO] Appended 79 samples from combined_data_17.csv to AlMn-Silicate.csv
# [INFO] Appended 4 samples from combined_data_17.csv to Mn-Oxide.csv
# [INFO] Appended 26 samples from combined_data_17.csv to REE-Silicate.csv
# [INFO] Appended 57 samples from combined_data_17.csv to Titanite.csv
# [INFO] Appended 20 samples from combined_data_17.csv to AlCa-Silicate.csv
# [INFO] Appended 8 samples from combined_data_17.csv to Apatite.csv
# [INFO] Finished processing combined_data_17.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_18.csv are in correct order
# [INFO] Appended 58 samples from combined_data_18.csv to Epidote.csv
# [INFO] Appended 68 samples from combined_data_18.csv to Amphibole.csv
# [INFO] Appended 124 samples from combined_data_18.csv to AlFe-Silicate.csv
# [INFO] Appended 221 samples from combined_data_18.csv to Fe-Silicate.csv
# [INFO] Appended 142 samples from combined_data_18.csv to Titanite.csv
# [INFO] Appended 173 samples from combined_data_18.csv to Al-Silicate.csv
# [INFO] Appended 143 samples from combined_data_18.csv to AlMn-Silicate.csv
# [INFO] Appended 17 samples from combined_data_18.csv to AlCa-Silicate.csv
# [INFO] Appended 7 samples from combined_data_18.csv to Apatite.csv
# [INFO] Appended 300 samples from combined_data_18.csv to AlK-Silicate.csv
# [INFO] Appended 1 samples from combined_data_18.csv to Fe-Sulphide.csv
# [INFO] Appended 110 samples from combined_data_18.csv to Quartz.csv
# [INFO] Appended 28 samples from combined_data_18.csv to Chromite.csv
# [INFO] Appended 102 samples from combined_data_18.csv to Leucoxene.csv
# [INFO] Appended 188 samples from combined_data_18.csv to Rutile.csv
# [INFO] Appended 81 samples from combined_data_18.csv to Mn-Oxide.csv
# [INFO] Appended 28 samples from combined_data_18.csv to Al-Oxide.csv
# [INFO] Appended 109 samples from combined_data_18.csv to Zircon.csv
# [INFO] Appended 70 samples from combined_data_18.csv to Monazite.csv
# [INFO] Appended 15 samples from combined_data_18.csv to Xenotime.csv
# [INFO] Appended 5 samples from combined_data_18.csv to Barite.csv
# [INFO] Appended 6 samples from combined_data_18.csv to Cassiterite.csv
# [INFO] Appended 2 samples from combined_data_18.csv to Celestine.csv
# [INFO] Appended 4 samples from combined_data_18.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 11 samples from combined_data_18.csv to Zn-Oxide.csv
# [INFO] Finished processing combined_data_18.csv
# --------------------------------------------------
# [INFO] Reordering columns for combined_data_19.csv
# [INFO] Appended 75 samples from combined_data_19.csv to Epidote.csv
# [INFO] Appended 79 samples from combined_data_19.csv to Amphibole.csv
# [INFO] Appended 96 samples from combined_data_19.csv to AlFe-Silicate.csv
# [INFO] Appended 172 samples from combined_data_19.csv to Fe-Silicate.csv
# [INFO] Appended 196 samples from combined_data_19.csv to Titanite.csv
# [INFO] Appended 87 samples from combined_data_19.csv to AlMn-Silicate.csv
# [INFO] Appended 15 samples from combined_data_19.csv to Fe-Sulphide.csv
# [INFO] Appended 107 samples from combined_data_19.csv to AlCa-Silicate.csv
# [INFO] Appended 364 samples from combined_data_19.csv to Quartz.csv
# [INFO] Appended 389 samples from combined_data_19.csv to AlK-Silicate.csv
# [INFO] Appended 35 samples from combined_data_19.csv to Al-Silicate.csv
# [INFO] Appended 12 samples from combined_data_19.csv to Apatite.csv
# [INFO] Appended 37 samples from combined_data_19.csv to Monazite.csv
# [INFO] Appended 16 samples from combined_data_19.csv to REE-Silicate.csv
# [INFO] Appended 40 samples from combined_data_19.csv to Zircon.csv
# [INFO] Appended 92 samples from combined_data_19.csv to Rutile.csv
# [INFO] Appended 33 samples from combined_data_19.csv to Leucoxene.csv
# [INFO] Appended 85 samples from combined_data_19.csv to Xenotime.csv
# [INFO] Appended 24 samples from combined_data_19.csv to Thorite.csv
# [INFO] Appended 6 samples from combined_data_19.csv to Carbonate.csv
# [INFO] Appended 12 samples from combined_data_19.csv to Chromite.csv
# [INFO] Appended 4 samples from combined_data_19.csv to Al-Oxide.csv
# [INFO] Appended 19 samples from combined_data_19.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 5 samples from combined_data_19.csv to Zn-Oxide.csv
# [INFO] Finished processing combined_data_19.csv
# --------------------------------------------------
# [INFO] Reordering columns for combined_data_20.csv
# [INFO] Appended 128 samples from combined_data_20.csv to AlFe-Silicate.csv
# [INFO] Appended 95 samples from combined_data_20.csv to Amphibole.csv
# [INFO] Appended 237 samples from combined_data_20.csv to Fe-Silicate.csv
# [INFO] Appended 262 samples from combined_data_20.csv to Titanite.csv
# [INFO] Appended 87 samples from combined_data_20.csv to AlMn-Silicate.csv
# [INFO] Appended 111 samples from combined_data_20.csv to Rutile.csv
# [INFO] Appended 96 samples from combined_data_20.csv to Leucoxene.csv
# [INFO] Appended 23 samples from combined_data_20.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 42 samples from combined_data_20.csv to Zn-Oxide.csv
# [INFO] Appended 146 samples from combined_data_20.csv to Quartz.csv
# [INFO] Appended 106 samples from combined_data_20.csv to AlK-Silicate.csv
# [INFO] Appended 9 samples from combined_data_20.csv to Al-Oxide.csv
# [INFO] Appended 90 samples from combined_data_20.csv to Epidote.csv
# [INFO] Appended 57 samples from combined_data_20.csv to Al-Silicate.csv
# [INFO] Appended 26 samples from combined_data_20.csv to Xenotime.csv
# [INFO] Appended 191 samples from combined_data_20.csv to AlCa-Silicate.csv
# [INFO] Appended 32 samples from combined_data_20.csv to Apatite.csv
# [INFO] Appended 91 samples from combined_data_20.csv to Zircon.csv
# [INFO] Appended 132 samples from combined_data_20.csv to Monazite.csv
# [INFO] Appended 39 samples from combined_data_20.csv to Barite.csv
# [INFO] Appended 3 samples from combined_data_20.csv to REE-Silicate.csv
# [INFO] Appended 4 samples from combined_data_20.csv to Nb-bearing phase.csv
# [INFO] Appended 5 samples from combined_data_20.csv to Fe-Sulphide.csv
# [INFO] Appended 2 samples from combined_data_20.csv to Chromite.csv
# [INFO] Finished processing combined_data_20.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_21.csv are in correct order
# [INFO] Appended 93 samples from combined_data_21.csv to AlFe-Silicate.csv
# [INFO] Appended 152 samples from combined_data_21.csv to Fe-Silicate.csv
# [INFO] Appended 111 samples from combined_data_21.csv to Rutile.csv
# [INFO] Appended 24 samples from combined_data_21.csv to Leucoxene.csv
# [INFO] Appended 91 samples from combined_data_21.csv to Zircon.csv
# [INFO] Appended 35 samples from combined_data_21.csv to Quartz.csv
# [INFO] Appended 60 samples from combined_data_21.csv to Epidote.csv
# [INFO] Appended 63 samples from combined_data_21.csv to Amphibole.csv
# [INFO] Appended 271 samples from combined_data_21.csv to Monazite.csv
# [INFO] Appended 27 samples from combined_data_21.csv to REE-Silicate.csv
# [INFO] Appended 67 samples from combined_data_21.csv to Al-Silicate.csv
# [INFO] Appended 185 samples from combined_data_21.csv to AlMn-Silicate.csv
# [INFO] Appended 3 samples from combined_data_21.csv to Xenotime.csv
# [INFO] Appended 156 samples from combined_data_21.csv to Titanite.csv
# [INFO] Appended 158 samples from combined_data_21.csv to Chromite.csv
# [INFO] Appended 67 samples from combined_data_21.csv to Fe-Sulphide.csv
# [INFO] Appended 41 samples from combined_data_21.csv to AlCa-Silicate.csv
# [INFO] Appended 1 samples from combined_data_21.csv to Thorite.csv
# [INFO] Appended 77 samples from combined_data_21.csv to AlK-Silicate.csv
# [INFO] Appended 54 samples from combined_data_21.csv to Cassiterite.csv
# [INFO] Appended 145 samples from combined_data_21.csv to Apatite.csv
# [INFO] Appended 23 samples from combined_data_21.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 24 samples from combined_data_21.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 22 samples from combined_data_21.csv to Zn-Oxide.csv
# [INFO] Appended 3 samples from combined_data_21.csv to Mn-Oxide.csv
# [INFO] Appended 58 samples from combined_data_21.csv to Barite.csv
# [INFO] Finished processing combined_data_21.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_22.csv are in correct order
# [INFO] Appended 84 samples from combined_data_22.csv to AlFe-Silicate.csv
# [INFO] Appended 190 samples from combined_data_22.csv to Rutile.csv
# [INFO] Appended 132 samples from combined_data_22.csv to Zircon.csv
# [INFO] Appended 265 samples from combined_data_22.csv to Monazite.csv
# [INFO] Appended 112 samples from combined_data_22.csv to Cassiterite.csv
# [INFO] Appended 115 samples from combined_data_22.csv to Al-Silicate.csv
# [INFO] Appended 135 samples from combined_data_22.csv to Quartz.csv
# [INFO] Appended 1 samples from combined_data_22.csv to Xenotime.csv
# [INFO] Appended 34 samples from combined_data_22.csv to Leucoxene.csv
# [INFO] Appended 8 samples from combined_data_22.csv to Nb-bearing phase.csv
# [INFO] Appended 70 samples from combined_data_22.csv to Epidote.csv
# [INFO] Appended 70 samples from combined_data_22.csv to Amphibole.csv
# [INFO] Appended 142 samples from combined_data_22.csv to Fe-Silicate.csv
# [INFO] Appended 172 samples from combined_data_22.csv to Titanite.csv
# [INFO] Appended 102 samples from combined_data_22.csv to AlMn-Silicate.csv
# [INFO] Appended 35 samples from combined_data_22.csv to Fe-Sulphide.csv
# [INFO] Appended 59 samples from combined_data_22.csv to AlCa-Silicate.csv
# [INFO] Appended 10 samples from combined_data_22.csv to Apatite.csv
# [INFO] Appended 99 samples from combined_data_22.csv to AlK-Silicate.csv
# [INFO] Appended 9 samples from combined_data_22.csv to Al-Oxide.csv
# [INFO] Appended 50 samples from combined_data_22.csv to Barite.csv
# [INFO] Appended 17 samples from combined_data_22.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 2 samples from combined_data_22.csv to Zn-Oxide.csv
# [INFO] Appended 32 samples from combined_data_22.csv to Celestine.csv
# [INFO] Appended 3 samples from combined_data_22.csv to Mn-Oxide.csv
# [INFO] Appended 52 samples from combined_data_22.csv to Chromite.csv
# [INFO] Finished processing combined_data_22.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_23.csv are in correct order
# [INFO] Appended 110 samples from combined_data_23.csv to Epidote.csv
# [INFO] Appended 115 samples from combined_data_23.csv to Amphibole.csv
# [INFO] Appended 134 samples from combined_data_23.csv to AlFe-Silicate.csv
# [INFO] Appended 249 samples from combined_data_23.csv to Fe-Silicate.csv
# [INFO] Appended 191 samples from combined_data_23.csv to Titanite.csv
# [INFO] Appended 248 samples from combined_data_23.csv to AlMn-Silicate.csv
# [INFO] Appended 67 samples from combined_data_23.csv to Quartz.csv
# [INFO] Appended 31 samples from combined_data_23.csv to Chromite.csv
# [INFO] Appended 45 samples from combined_data_23.csv to Zircon.csv
# [INFO] Appended 69 samples from combined_data_23.csv to Monazite.csv
# [INFO] Appended 73 samples from combined_data_23.csv to AlK-Silicate.csv
# [INFO] Appended 82 samples from combined_data_23.csv to Al-Silicate.csv
# [INFO] Appended 103 samples from combined_data_23.csv to AlCa-Silicate.csv
# [INFO] Appended 8 samples from combined_data_23.csv to Leucoxene.csv
# [INFO] Appended 48 samples from combined_data_23.csv to Rutile.csv
# [INFO] Appended 49 samples from combined_data_23.csv to Apatite.csv
# [INFO] Appended 43 samples from combined_data_23.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 17 samples from combined_data_23.csv to Xenotime.csv
# [INFO] Appended 9 samples from combined_data_23.csv to W-Oxide.csv
# [INFO] Appended 26 samples from combined_data_23.csv to Zn-Oxide.csv
# [INFO] Appended 2 samples from combined_data_23.csv to REE-Silicate.csv
# [INFO] Appended 22 samples from combined_data_23.csv to Columbite_Mn.csv
# [INFO] Appended 1 samples from combined_data_23.csv to Mn-Oxide.csv
# [INFO] Appended 15 samples from combined_data_23.csv to Al-Oxide.csv
# ...
# [INFO] Appended 75 samples from combined_data_71.csv to REE-Silicate.csv
# [INFO] Appended 18 samples from combined_data_71.csv to Nb-bearing phase.csv
# [INFO] Appended 55 samples from combined_data_71.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 12 samples from combined_data_71.csv to W-Oxide.csv
# [INFO] Appended 81 samples from combined_data_71.csv to Carbonate.csv
# [INFO] Appended 60 samples from combined_data_71.csv to Celestine.csv
# [INFO] Appended 9 samples from combined_data_71.csv to Mn-Oxide.csv
# [INFO] Appended 210 samples from combined_data_71.csv to Cassiterite.csv
# [INFO] Appended 97 samples from combined_data_71.csv to Cu-Oxide.csv
# [INFO] Appended 26 samples from combined_data_71.csv to AlCa-Silicate.csv
# [INFO] Appended 94 samples from combined_data_71.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 22 samples from combined_data_71.csv to Columbite_Mn.csv
# [INFO] Finished processing combined_data_71.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_72.csv are in correct order
# [INFO] Appended 34 samples from combined_data_72.csv to Amphibole.csv
# [INFO] Appended 48 samples from combined_data_72.csv to AlFe-Silicate.csv
# [INFO] Appended 39 samples from combined_data_72.csv to Cassiterite.csv
# [INFO] Appended 187 samples from combined_data_72.csv to Chromite.csv
# [INFO] Appended 282 samples from combined_data_72.csv to Carbonate.csv
# [INFO] Appended 63 samples from combined_data_72.csv to Al-Oxide.csv
# [INFO] Appended 180 samples from combined_data_72.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 53 samples from combined_data_72.csv to Celestine.csv
# [INFO] Appended 96 samples from combined_data_72.csv to Columbite_Mn.csv
# [INFO] Appended 36 samples from combined_data_72.csv to Epidote.csv
# [INFO] Appended 49 samples from combined_data_72.csv to Barite.csv
# [INFO] Appended 171 samples from combined_data_72.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 1 samples from combined_data_72.csv to REE-Silicate.csv
# [INFO] Appended 66 samples from combined_data_72.csv to Zn-Oxide.csv
# [INFO] Appended 55 samples from combined_data_72.csv to Fe-Sulphide.csv
# [INFO] Appended 33 samples from combined_data_72.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 21 samples from combined_data_72.csv to Mn-Oxide.csv
# [INFO] Appended 51 samples from combined_data_72.csv to Zircon.csv
# [INFO] Appended 69 samples from combined_data_72.csv to Cu-Oxide.csv
# [INFO] Appended 79 samples from combined_data_72.csv to Molybdenite.csv
# [INFO] Appended 8 samples from combined_data_72.csv to Leucoxene.csv
# [INFO] Appended 137 samples from combined_data_72.csv to AlCa-Silicate.csv
# [INFO] Appended 149 samples from combined_data_72.csv to W-Oxide.csv
# [INFO] Appended 25 samples from combined_data_72.csv to Nb-bearing phase.csv
# [INFO] Appended 114 samples from combined_data_72.csv to Xenotime.csv
# [INFO] Appended 17 samples from combined_data_72.csv to Thorite.csv
# [INFO] Appended 35 samples from combined_data_72.csv to Apatite.csv
# [INFO] Finished processing combined_data_72.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_73.csv are in correct order
# [INFO] Appended 64 samples from combined_data_73.csv to Epidote.csv
# [INFO] Appended 71 samples from combined_data_73.csv to Amphibole.csv
# [INFO] Appended 238 samples from combined_data_73.csv to Barite.csv
# [INFO] Appended 84 samples from combined_data_73.csv to Chromite.csv
# [INFO] Appended 41 samples from combined_data_73.csv to Carbonate.csv
# [INFO] Appended 22 samples from combined_data_73.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 24 samples from combined_data_73.csv to Al-Oxide.csv
# [INFO] Appended 48 samples from combined_data_73.csv to Zn-Oxide.csv
# [INFO] Appended 4 samples from combined_data_73.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 84 samples from combined_data_73.csv to AlFe-Silicate.csv
# [INFO] Appended 467 samples from combined_data_73.csv to Fe-Sulphide.csv
# [INFO] Appended 63 samples from combined_data_73.csv to AlCa-Silicate.csv
# [INFO] Appended 13 samples from combined_data_73.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 30 samples from combined_data_73.csv to Mn-Oxide.csv
# [INFO] Appended 12 samples from combined_data_73.csv to Cu-Oxide.csv
# [INFO] Appended 35 samples from combined_data_73.csv to Molybdenite.csv
# [INFO] Appended 62 samples from combined_data_73.csv to W-Oxide.csv
# [INFO] Appended 64 samples from combined_data_73.csv to Nb-bearing phase.csv
# [INFO] Appended 36 samples from combined_data_73.csv to Xenotime.csv
# [INFO] Appended 48 samples from combined_data_73.csv to Thorite.csv
# [INFO] Appended 31 samples from combined_data_73.csv to Columbite_Mn.csv
# [INFO] Appended 105 samples from combined_data_73.csv to Zircon.csv
# [INFO] Appended 327 samples from combined_data_73.csv to Leucoxene.csv
# [INFO] Appended 30 samples from combined_data_73.csv to REE-Silicate.csv
# [INFO] Appended 2 samples from combined_data_73.csv to Apatite.csv
# [INFO] Finished processing combined_data_73.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_74.csv are in correct order
# [INFO] Appended 127 samples from combined_data_74.csv to Epidote.csv
# [INFO] Appended 135 samples from combined_data_74.csv to Amphibole.csv
# [INFO] Appended 187 samples from combined_data_74.csv to AlFe-Silicate.csv
# [INFO] Appended 12 samples from combined_data_74.csv to Mn-Oxide.csv
# [INFO] Appended 248 samples from combined_data_74.csv to AlCa-Silicate.csv
# [INFO] Appended 8 samples from combined_data_74.csv to Al-Oxide.csv
# [INFO] Appended 28 samples from combined_data_74.csv to REE-Silicate.csv
# [INFO] Appended 103 samples from combined_data_74.csv to Leucoxene.csv
# [INFO] Appended 240 samples from combined_data_74.csv to Apatite.csv
# [INFO] Appended 398 samples from combined_data_74.csv to Zircon.csv
# [INFO] Appended 231 samples from combined_data_74.csv to Barite.csv
# [INFO] Appended 44 samples from combined_data_74.csv to Fe-Sulphide.csv
# [INFO] Appended 1 samples from combined_data_74.csv to Nb-bearing phase.csv
# [INFO] Appended 43 samples from combined_data_74.csv to Chromite.csv
# [INFO] Appended 37 samples from combined_data_74.csv to Xenotime.csv
# [INFO] Appended 16 samples from combined_data_74.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 33 samples from combined_data_74.csv to Zn-Oxide.csv
# [INFO] Appended 73 samples from combined_data_74.csv to Cassiterite.csv
# [INFO] Appended 11 samples from combined_data_74.csv to Thorite.csv
# [INFO] Appended 6 samples from combined_data_74.csv to Cu-Oxide.csv
# [INFO] Appended 16 samples from combined_data_74.csv to Celestine.csv
# [INFO] Appended 11 samples from combined_data_74.csv to Fe-sulphide_Pb.csv
# [INFO] Finished processing combined_data_74.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_75.csv are in correct order
# [INFO] Appended 36 samples from combined_data_75.csv to Epidote.csv
# [INFO] Appended 32 samples from combined_data_75.csv to Amphibole.csv
# [INFO] Appended 36 samples from combined_data_75.csv to AlFe-Silicate.csv
# [INFO] Appended 192 samples from combined_data_75.csv to AlCa-Silicate.csv
# [INFO] Appended 37 samples from combined_data_75.csv to Zircon.csv
# [INFO] Appended 26 samples from combined_data_75.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 120 samples from combined_data_75.csv to Barite.csv
# [INFO] Appended 26 samples from combined_data_75.csv to Leucoxene.csv
# [INFO] Appended 122 samples from combined_data_75.csv to Xenotime.csv
# [INFO] Appended 99 samples from combined_data_75.csv to Celestine.csv
# [INFO] Appended 86 samples from combined_data_75.csv to Apatite.csv
# [INFO] Appended 60 samples from combined_data_75.csv to Al-Oxide.csv
# [INFO] Appended 132 samples from combined_data_75.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 107 samples from combined_data_75.csv to Cu-Oxide.csv
# [INFO] Appended 38 samples from combined_data_75.csv to Cassiterite.csv
# [INFO] Appended 135 samples from combined_data_75.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 128 samples from combined_data_75.csv to Chromite.csv
# [INFO] Appended 166 samples from combined_data_75.csv to Carbonate.csv
# [INFO] Appended 89 samples from combined_data_75.csv to Columbite_Mn.csv
# [INFO] Appended 63 samples from combined_data_75.csv to Fe-Sulphide.csv
# [INFO] Appended 25 samples from combined_data_75.csv to Zn-Oxide.csv
# [INFO] Appended 18 samples from combined_data_75.csv to Mn-Oxide.csv
# [INFO] Appended 72 samples from combined_data_75.csv to Molybdenite.csv
# [INFO] Appended 2 samples from combined_data_75.csv to REE-Silicate.csv
# [INFO] Appended 143 samples from combined_data_75.csv to W-Oxide.csv
# [INFO] Appended 17 samples from combined_data_75.csv to Nb-bearing phase.csv
# [INFO] Appended 20 samples from combined_data_75.csv to Thorite.csv
# [INFO] Finished processing combined_data_75.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_76.csv are in correct order
# [INFO] Appended 36 samples from combined_data_76.csv to Epidote.csv
# [INFO] Appended 78 samples from combined_data_76.csv to Zircon.csv
# [INFO] Appended 270 samples from combined_data_76.csv to Xenotime.csv
# [INFO] Appended 42 samples from combined_data_76.csv to Columbite_Mn.csv
# [INFO] Appended 42 samples from combined_data_76.csv to Amphibole.csv
# [INFO] Appended 42 samples from combined_data_76.csv to AlFe-Silicate.csv
# [INFO] Appended 17 samples from combined_data_76.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 59 samples from combined_data_76.csv to Zn-Oxide.csv
# [INFO] Appended 59 samples from combined_data_76.csv to Apatite.csv
# [INFO] Appended 76 samples from combined_data_76.csv to Al-Oxide.csv
# [INFO] Appended 141 samples from combined_data_76.csv to Fe-Sulphide_Cu.csv
# [INFO] Appended 81 samples from combined_data_76.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 65 samples from combined_data_76.csv to Cu-Oxide.csv
# [INFO] Appended 132 samples from combined_data_76.csv to Cassiterite.csv
# [INFO] Appended 59 samples from combined_data_76.csv to Barite.csv
# [INFO] Appended 112 samples from combined_data_76.csv to AlCa-Silicate.csv
# [INFO] Appended 152 samples from combined_data_76.csv to Chromite.csv
# [INFO] Appended 199 samples from combined_data_76.csv to Carbonate.csv
# [INFO] Appended 33 samples from combined_data_76.csv to Celestine.csv
# [INFO] Appended 41 samples from combined_data_76.csv to Fe-Sulphide.csv
# [INFO] Appended 34 samples from combined_data_76.csv to Molybdenite.csv
# [INFO] Appended 17 samples from combined_data_76.csv to Mn-Oxide.csv
# [INFO] Appended 78 samples from combined_data_76.csv to W-Oxide.csv
# [INFO] Appended 20 samples from combined_data_76.csv to Nb-bearing phase.csv
# [INFO] Appended 162 samples from combined_data_76.csv to Thorite.csv
# [INFO] Appended 2 samples from combined_data_76.csv to REE-Silicate.csv
# [INFO] Finished processing combined_data_76.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_77.csv are in correct order
# [INFO] Appended 170 samples from combined_data_77.csv to Epidote.csv
# [INFO] Appended 190 samples from combined_data_77.csv to Amphibole.csv
# [INFO] Appended 215 samples from combined_data_77.csv to AlFe-Silicate.csv
# [INFO] Appended 39 samples from combined_data_77.csv to Zircon.csv
# [INFO] Appended 84 samples from combined_data_77.csv to Cassiterite.csv
# [INFO] Appended 96 samples from combined_data_77.csv to Apatite.csv
# [INFO] Appended 394 samples from combined_data_77.csv to Xenotime.csv
# [INFO] Appended 234 samples from combined_data_77.csv to Thorite.csv
# [INFO] Appended 78 samples from combined_data_77.csv to REE-Silicate.csv
# [INFO] Appended 34 samples from combined_data_77.csv to Al-Oxide.csv
# [INFO] Appended 3 samples from combined_data_77.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 40 samples from combined_data_77.csv to Zn-Oxide.csv
# [INFO] Appended 162 samples from combined_data_77.csv to AlCa-Silicate.csv
# [INFO] Appended 11 samples from combined_data_77.csv to Mn-Oxide.csv
# [INFO] Appended 34 samples from combined_data_77.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 11 samples from combined_data_77.csv to Columbite_Mn.csv
# [INFO] Appended 3 samples from combined_data_77.csv to Cu-Oxide.csv
# [INFO] Appended 18 samples from combined_data_77.csv to Nb-bearing phase.csv
# [INFO] Appended 70 samples from combined_data_77.csv to Barite.csv
# [INFO] Appended 6 samples from combined_data_77.csv to Carbonate.csv
# [INFO] Appended 20 samples from combined_data_77.csv to Fe-Sulphide.csv
# [INFO] Appended 87 samples from combined_data_77.csv to Chromite.csv
# [INFO] Appended 2 samples from combined_data_77.csv to Celestine.csv
# [INFO] Finished processing combined_data_77.csv
# --------------------------------------------------
# [INFO] Columns in combined_data_78.csv are in correct order
# [INFO] Appended 167 samples from combined_data_78.csv to Epidote.csv
# [INFO] Appended 194 samples from combined_data_78.csv to Amphibole.csv
# [INFO] Appended 330 samples from combined_data_78.csv to AlFe-Silicate.csv
# [INFO] Appended 268 samples from combined_data_78.csv to Chromite.csv
# [INFO] Appended 319 samples from combined_data_78.csv to AlCa-Silicate.csv
# [INFO] Appended 85 samples from combined_data_78.csv to Apatite.csv
# [INFO] Appended 1 samples from combined_data_78.csv to Carbonate.csv
# [INFO] Appended 31 samples from combined_data_78.csv to Al-Oxide.csv
# [INFO] Appended 56 samples from combined_data_78.csv to Xenotime.csv
# [INFO] Appended 13 samples from combined_data_78.csv to Columbite_Mn.csv
# [INFO] Appended 27 samples from combined_data_78.csv to REE-Silicate.csv
# [INFO] Appended 23 samples from combined_data_78.csv to AlFe-Silicate_Zn.csv
# [INFO] Appended 18 samples from combined_data_78.csv to Zn-Oxide.csv
# [INFO] Appended 5 samples from combined_data_78.csv to Celestine.csv
# [INFO] Appended 14 samples from combined_data_78.csv to Fe-sulphide_Pb.csv
# [INFO] Appended 12 samples from combined_data_78.csv to Mn-Oxide.csv
# [INFO] Appended 384 samples from combined_data_78.csv to Barite.csv
# [INFO] Appended 9 samples from combined_data_78.csv to Fe-Sulphide.csv
# [INFO] Appended 8 samples from combined_data_78.csv to Nb-bearing phase.csv
# [INFO] Appended 1 samples from combined_data_78.csv to Thorite.csv
# [INFO] Appended 7 samples from combined_data_78.csv to W-Oxide.csv
# [INFO] Appended 35 samples from combined_data_78.csv to Cu-Oxide.csv
# [INFO] Appended 4 samples from combined_data_78.csv to Fe-Sulphide_Cu.csv
# [INFO] Finished processing combined_data_78.csv
# --------------------------------------------------
#
# [SUMMARY]
# For Fe-Oxide.csv: Total samples = 19800
# For Background.csv: Total samples = 19800
# For Ilmenite.csv: Total samples = 19800
# For Epidote.csv: Total samples = 24721
# For Amphibole.csv: Total samples = 25101
# For AlFe-Silicate.csv: Total samples = 27169
# For Fe-Silicate.csv: Total samples = 27800
# For Titanite.csv: Total samples = 27800
# For AlMn-Silicate.csv: Total samples = 27800
# For Rutile.csv: Total samples = 27800
# For Zircon.csv: Total samples = 27800
# For Monazite.csv: Total samples = 27419
# For Quartz.csv: Total samples = 27800
# For Cassiterite.csv: Total samples = 22140
# For AlK-Silicate.csv: Total samples = 27800
# For Barite.csv: Total samples = 26036
# For Al-Silicate.csv: Total samples = 27800
# For Chromite.csv: Total samples = 24524
# For Leucoxene.csv: Total samples = 18800
# For Fe-Sulphide.csv: Total samples = 13764
# For AlCa-Silicate.csv: Total samples = 17513
# For Apatite.csv: Total samples = 14128
# For Xenotime.csv: Total samples = 12375
# For Carbonate.csv: Total samples = 11919
# For Thorite.csv: Total samples = 7503
# For AlFe-Silicate_Zn.csv: Total samples = 5127
# For Al-Oxide.csv: Total samples = 5818
# For Fe-Sulphide_Cu.csv: Total samples = 7381
# For W-Oxide.csv: Total samples = 6141
# For Zn-Oxide.csv: Total samples = 5426
# For Fe-sulphide_Pb.csv: Total samples = 6199
# For Celestine.csv: Total samples = 5677
# For Mn-Oxide.csv: Total samples = 4012
# For Columbite_Mn.csv: Total samples = 4719
# For Cu-Oxide.csv: Total samples = 4582
# For Nb-bearing phase.csv: Total samples = 2605
# For REE-Silicate.csv: Total samples = 2459
# For Molybdenite.csv: Total samples = 2821
#
# [DONE] All files processed.
